# %%
import pandas as pd
pd.set_option('display.height', 1000)
pd.set_option('display.max_rows', 5000)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
import tensorflow as tf

# %%
df = pd.read_excel('NBA.xlsx',sheetname='COMBO')
#df = pd.read_excel('2018NBA_data.xlsx',sheetname='All Team Data')
df.head()

# %%
df = df.drop(df[(df.Exp == 'R') | (df.Exp=='INJURED') | (df.Exp.isnull())].index)
df = df.drop(df[(df.Name=='')].index)
df = df.drop(df[(df.Season=='')].index)
df = df.drop(df[(df.Name=='DeAndre Liggins')].index)

# %%
def region_to_numeric(a):
    if a == 'Left':
        return 1
    if a == 'Right':
        return 0


df['Shoots'] = df['Shoots'].apply(region_to_numeric)

# %%
df.dtypes
#df = pd.DataFrame(Shoots,Exp,Season,Tm,Lg,Pos, dtype='float')
df[['Shoots', 'Exp']] = df[['Shoots', 'Exp']].astype(float)

# %%
df.rename(columns={'FG%': 'FG_R', '3P': 'ThreeP_R','3PA': 'ThreePA_R', '3P%': 'ThreePPct_R','2P': 'TwoP_R',
                   '2PA': 'TwoPA_R', '2P%': 'TwoPPct_R','eFG%': 'eFG_R','FT%': 'FTPct_R'}, inplace=True)

# %%
df.describe()

# %%
sb.heatmap(df.isnull())

# %%
df.fillna(method='ffill',inplace=True)
df.isnull().sum()

# %%
sb.heatmap(df.isnull())

# %% [markdown]
# # Create a function to drop Injured or Not playing players from each team

# %%
dfgrouped = pd.DataFrame()
dfgrouped = df.groupby(['Name']).agg(['mean'])
dfgrouped.head()

# %%
mf = df.groupby('Name')
mf.head(10)
player_dict = {}
#d = pd.DataFrame
for name,group in mf:
        Shoots_mean    = group.Shoots.mean()
        Exp_mean       = group.Exp.mean()
        Age_mean       = group.Age.mean()
        G_mean         = group.G.mean()
        GS_mean        = group.GS.mean()
        MP_mean        = group.MP.mean()
        FG_mean        = group.FG.mean()
        FGA_mean       = group.FGA.mean()
        FG_R_mean      = group.FG_R.mean()
        ThreeP_R_mean  = group.ThreeP_R.mean()
        ThreePA_R_mean = group.ThreePA_R.mean()
        ThreePPct_R    = group.ThreePPct_R.mean()
        TwoP_R         = group.TwoP_R.mean()
        TwoPA_R        = group.TwoPA_R.mean()
        TwoPPct_R      = group.TwoPPct_R.mean()
        eFG_R          = group.eFG_R.mean()
        FT             = group.FT.mean()
        FTA            = group.FTA.mean()
        FTPct_R        = group.FTPct_R.mean()
        ORB            = group.ORB.mean()
        DRB            = group.DRB.mean()
        TRB            = group.TRB.mean()
        AST            = group.AST.mean()
        STL            = group.STL.mean()
        BLK            = group.BLK.mean()
        TOV            = group.TOV.mean()
        PF             = group.PF.mean()
        PTS            = group.PTS.mean()
         
    
        player_dict[name] = [Shoots_mean,
                                        Exp_mean,
                                        Age_mean,
                                        G_mean,
                                        GS_mean,
                                        MP_mean,
                                        FG_mean,
                                        FGA_mean,
                                        FG_R_mean,
                                        ThreeP_R_mean,
                                        ThreePA_R_mean,
                                        ThreePPct_R,
                                        TwoP_R,
                                        TwoPA_R,
                                        TwoPPct_R,
                                        eFG_R,
                                        FT,
                                        FTA,
                                        FTPct_R,
                                        ORB,
                                        DRB,
                                        TRB,
                                        AST,
                                        STL,
                                        BLK,
                                        TOV,
                                        PF,
                                        PTS]
        new_df = pd.DataFrame(player_dict)


    
    

        print('Name '+str(name) 
                 + ' Shoots_mean'+str(Shoots_mean)
                 + ' Exp_mean'+str(Exp_mean)                          
                 + ' Age_mean'+str(Age_mean)                                                  
                 + ' G_mean '+str(G_mean)
                 + ' GS_mean '+str(GS_mean)
                 + ' MP_mean '+str(MP_mean)
                 + ' FG_mean '+str(FG_mean)
                 + ' FGA_mean '+str(FGA_mean)
                 + ' FG_R_mean '+str(FG_R_mean)
                 + ' ThreeP_R_mean '+str(ThreeP_R_mean)
                 + ' ThreePA_R_mean '+str(ThreePA_R_mean)
                 + ' ThreePPct_R '+str(ThreePPct_R)
                 + ' TwoP_R '+str(TwoP_R)
                 + ' TwoPA_R '+str(TwoPA_R)
                 + ' TwoPPct_R '+str(TwoPPct_R)
                 + ' eFG_R '+str(eFG_R)
                 + ' FT '+str(FT)
                 + ' FTA '+str(FTA)
                 + ' FTPct_R '+str(FTPct_R)
                 + ' ORB '+str(ORB)
                 + ' TRB '+str(TRB)
                 + ' AST '+str(AST)
                 + ' STL '+str(STL)
                 + ' BLK '+str(BLK)
                 + ' TOV '+str(TOV)
                 + ' PF '+str(PF)
                 + ' PTS '+str(PTS)
                 + '#################-------END------################')

# %%
df_intd = new_df.transpose()
df_intd
df_intd.columns = ['Shoots_mean',                    
                'Exp_mean', 
                'Age_mean',
                'G_mean',
                'GS_mean',
                'MP_mean',
                'FG_mean',
                'FGA_mean',
                'FG_R_mean',
                'ThreeP_R_mean',
                'ThreePA_R_mean',
                'ThreePPct_R',
                'TwoP_R',
                'TwoPA_R',
                'TwoPPct_R',
                'eFG_R',
                'FT',
                'FTA',
                'FTPct_R',
                'ORB',
                'DRB',
                'TRB',
                'AST',
                'STL',
                'BLK',
                'TOV',
                'PF',
                'PTS']

# %%
df_intd.head()
features = df_intd.reset_index()
features

# %%
features=features.rename(columns = {'index':'Name'})
features

# %%
features.isnull().sum()

# %%
Salary = pd.read_excel('NBA_name.xlsx',sheetname='Salary_All')
#Salary = pd.read_excel('2018NBA_data.xlsx',sheetname='All Salary')
Salary.head()
#Salary.dropna()
Salary.isnull().sum()

# %%
sb.heatmap(Salary.isnull(),yticklabels=False,cbar=True)

# %%
merged = features.merge(Salary, how='left')
merged.Team.unique()
merged.to_excel('Analysis.xlsx')
#same players in different teams is creating a duplicate row

# %%
#merged.drop_duplicates(keep='first')

merged.isnull().sum()
#merged.groupby('Name', group_keys=False).apply(lambda x: x.loc[x.Salary.idxmax()])

# %%
merged.dropna(how='any',inplace=True)

# %%
nulls = lambda merged: merged[merged.isnull().any(axis=1)]
nulls(merged)

# %%
merged.Team = pd.Categorical(merged.Team)
merged['Team_code'] = merged.Team.cat.codes

# %%
Team_Code_Sorted = merged.sort_values('Team_code', ascending=True)
Team_Code_Sorted

# %%
merged_drop_dups = merged.sort_values('Salary', ascending=False).drop_duplicates('Name').sort_index().reset_index(drop=True)
merged_drop_dups.head()

# %%
cols_drop = merged_drop_dups[['Name','Team']]
merged1 = merged_drop_dups.drop(cols_drop, axis=1)
merged1

# %%
merged_columns=np.transpose(merged1)
cov=pd.DataFrame(np.cov(merged_columns))
cov.columns = merged1.columns
cov.index = merged1.columns
cov

# %%
cor=pd.DataFrame(np.corrcoef(merged_columns))
cor.columns = merged1.columns
cor.index = merged1.columns
cor

# %%
sb.heatmap(merged1.corr(),cmap='coolwarm')
plt.title('NBA.corr()')

# %%
merged_drop_dups.head()

# %%
#visul = merged1.hist(figsize=[20,20]);

# %%
# Reading Team Score of the Last 3 years
Team_Score = pd.read_excel('Team Score.xlsx',sheetname='Sheet2')
Team_Score.head()

# %%
Team_Score['Team_Score_Sum'] = Team_Score['Team Stats 2014']+Team_Score['Team Stats 2015']+Team_Score['Team Stats 2016']
Team_Score = Team_Score.sort_values('Team', ascending=True)
Team_Score.head(30)

# %%
Team_Score = Team_Score.sort_values('Team_Score_Sum', ascending=False)
Team_Score.head(30)

# %%
Team_Score.describe()

# %%
def Team_Score(data):
#    Salary = data[0]
#    data = data[]
   
    if data == 'Atlanta Hawks':
        
    
            return 1.770  
    
    
    if data == 'Boston Celtics':
            
            return 1.653
        
        
    if data == 'Brooklyn Nets':
      
        
            return 0.955
        
    if data == 'Charlotte Hornets':        
   
        
            return 1.414
      
    if data == 'Chicago Bulls':
       
        
            return 1.597
       
    if data == 'Cleveland Cavaliers':
         
        
            return 2.006
       
    if data == 'Dallas Mavericks':
       
        
            return 1.482
        
    if data == 'Denver Nuggets':
        
        
            return 1.256
        
    if data == 'Detroit Pistons':
         
        
            return 1.353
        
    if data == 'Golden State Warrior':
        
        
            return 2.474
         
    if data == 'Houston Rockets':
        
        
            return 1.796
        
    if data == 'Indiana Pacers':
       
       
            return 1.49
       
    if data == 'Los Angeles Clippers':
        
        
            return 1.888
        
    if data == 'Los Angeles Lakers':
        
      
            return 0.78
        
    if data == 'Memphis Grizzlies':   
       
        
            return 1.655
       
    if data == 'Miami Heat':
   
       
            return 1.524
     
    if data == 'Milwaukee Bucks':
       
       
            return 1.391
     
    if data == 'Minnesota Timberwolves':   
     
       
            return 0.927
        
    if data == 'New Orleans Pelicans':
        
       
            return 1.304
        
    if data == 'New York Knicks':
         
       
            return 0.975
         
    if data == 'Oklahoma City Thunder':
        
       
            return 1.761
        
    if data == 'Orlando Magic':
     
        
            return 1.086
   
    if data == 'Philadelphia 76ers':
    
        
            return 0.684
        
    if data == 'Phoenix Suns':
        
        
            return 1.05
         
    if data == 'Portland Trail Blazers':
       
        
            return 1.602
        
    if data == 'Sacramento Kings':
       
        
            return 1.146
    if data == 'SAN ANTONIO':
       
        
            return 2.149  
    if data == 'Toronto Raptors':
       
      
            return 1.815
         
    if data == 'Utah Jazz':
       
        
            return 1.542
         
    if data == 'Washington Wizards':
      
       
            return 1.655
         
    else:
        return 99999

# %%
merged_drop_dups['Team_Score'] = merged_drop_dups['Team'].apply(Team_Score)
merged_drop_dups.Team_Score.value_counts()
merged_drop_dups.head(30)

# %%
def Team_Label(data):
#    Salary = data[0]
#    data = data[]

     if data >= 1.47:
      
           return 1
     else:
       
           return 0

# %%
merged_drop_dups['Team_Label'] = merged_drop_dups['Team_Score'].apply(Team_Label)
merged_drop_dups.Team_Label.value_counts()
merged_drop_dups.head(74)

# %%
# Feature Selection
# Define X and y
cols_drop = merged_drop_dups[['Name','Team','Team_Label']]
X = merged_drop_dups.drop(cols_drop, axis=1)
X.head()
#2,3,4,5,6 8 11 28 29 31 
X.columns
'Exp_mean', 'Age_mean', 'G_mean', 'GS_mean', 'MP_mean','FGA_mean','ThreeP_R_mean','PTS','Salary','Team_Score'

# %%
y = merged_drop_dups['Team_Label']
y.head()

# %%
# Recursive Feature Elimination
#from sklearn import datasets
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
# load the iris datasets
dataset = merged_drop_dups
# create a base classifier used to evaluate a subset of attributes
model = LogisticRegression()
# create the RFE model and select 3 attributes
rfe = RFE(model, 10)
rfe = rfe.fit(X, y)
# summarize the selection of the attributes
print(rfe.support_)
print(rfe.ranking_)
#2,3,4,5,6 8 11 28 29 31

# %%
# Feature Importance
from sklearn import datasets
from sklearn import metrics
from sklearn.ensemble import ExtraTreesClassifier
# load the iris datasets
dataset = merged_drop_dups
# fit an Extra Trees model to the data
model = ExtraTreesClassifier()
model.fit(X, y)
# display the relative importance of each attribute
print(model.feature_importances_)

# %%
cor=pd.DataFrame(np.corrcoef(merged_columns))
cor.columns = merged1.columns
cor.index = merged1.columns
cor

# %%
merged_drop_dups.corr()

# %%
sb.heatmap(merged_drop_dups.corr(),cmap='coolwarm')
plt.title('NBA_Correlation')

# %%
X_Features = merged_drop_dups[['Exp_mean', 'Age_mean', 'G_mean', 'GS_mean', 'MP_mean','FGA_mean','ThreeP_R_mean','PTS','Salary','Team_Score','Team_code']]
y = merged_drop_dups['Team_Label']

# %%
X_Features

# %%
merged_drop_dups.head()

# %%
print(merged_drop_dups[['Exp_mean', 'Age_mean', 'G_mean', 'GS_mean', 'MP_mean','FGA_mean','ThreeP_R_mean',
                         'PTS','Salary','Team_Score','Team_code','Team_Label']].corr())

# %%
sb.boxplot(x='Salary', y ='Team', data = merged_drop_dups)

# %%
dfgrouped = pd.DataFrame()
dfgrouped = merged_drop_dups.groupby(['Team']).agg(['mean'])
dfgrouped.head(30)

# %%
mf_merged_drop_dups = merged_drop_dups.groupby('Team')
bb = '#############################################################################################'
cc = '@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@'
for a,b in mf_merged_drop_dups:
    print('The name of the Team : ' +str(a))
    print('The mean salary of the Team  : ' +str(b.Salary.mean()))
    print('The max salary of the Team  : ' +str(b.Salary.max()))
    print('The median salary of the Team  : ' +str(b.Salary.median()))
    print('The min salary of the Team  : ' +str(b.Salary.min()))
    print('The 75% of max salary of the Team  : ' +str(b.Salary.max()*0.75))
    print('The 50% of max salary of the Team  : ' +str(b.Salary.max()*0.50))
    print('The 25% of max salary of the Team  : ' +str(b.Salary.max()*0.25))
    print(cc)
    print('The mean Exp of the Team  : ' +str(b.Exp_mean.mean()))
    print('The max Exp of the Team  : ' +str(b.Exp_mean.max()))
    print('The median Exp of the Team  : ' +str(b.Exp_mean.median()))
    print('The min Exp of the Team  : ' +str(b.Exp_mean.min()))
    print('The 75% of max Exp of the Team  : ' +str(b.Exp_mean.max()*0.75))
    print('The 50% of max Exp of the Team  : ' +str(b.Exp_mean.max()*0.50))
    print('The 25% of max Exp of the Team  : ' +str(b.Exp_mean.max()*0.25))
    print(cc)
    print('The mean Age of the Team  : ' +str(b.Age_mean.mean()))
    print('The max Age of the Team  : ' +str(b.Age_mean.max()))
    print('The median Age of the Team  : ' +str(b.Age_mean.median()))
    print('The min Age of the Team  : ' +str(b.Age_mean.min()))
    print('The 75% of max Age of the Team  : ' +str(b.Age_mean.max()*0.75))
    print('The 50% of max Age of the Team  : ' +str(b.Age_mean.max()*0.50))
    print('The 25% of max Age of the Team  : ' +str(b.Age_mean.max()*0.25))
    print(cc)
    print('The mean G of the Team  : ' +str(b.G_mean.mean()))
    print('The max G of the Team  : ' +str(b.G_mean.max()))
    print('The median G of the Team  : ' +str(b.G_mean.median()))
    print('The min G of the Team  : ' +str(b.G_mean.min()))
    print('The 75% of max G of the Team  : ' +str(b.G_mean.max()*0.75))
    print('The 50% of max G of the Team  : ' +str(b.G_mean.max()*0.50))
    print('The 25% of max G of the Team  : ' +str(b.G_mean.max()*0.25))
    print(cc)
    print('The mean GS of the Team  : ' +str(b.GS_mean.mean()))
    print('The max GS of the Team  : ' +str(b.GS_mean.max()))
    print('The median GS of the Team  : ' +str(b.GS_mean.median()))
    print('The min GS of the Team  : ' +str(b.GS_mean.min()))
    print('The 75% of max GS of the Team  : ' +str(b.GS_mean.max()*0.75))
    print('The 50% of max GS of the Team  : ' +str(b.GS_mean.max()*0.50))
    print('The 25% of max GS of the Team  : ' +str(b.GS_mean.max()*0.25))
    print(cc)
    print('The mean MP of the Team  : ' +str(b.MP_mean.mean()))
    print('The max MP of the Team  : ' +str(b.MP_mean.max()))
    print('The median MP of the Team  : ' +str(b.MP_mean.median()))
    print('The min MP of the Team  : ' +str(b.MP_mean.min()))
    print('The 75% of max MP of the Team  : ' +str(b.MP_mean.max()*0.75))
    print('The 50% of max MP of the Team  : ' +str(b.MP_mean.max()*0.50))
    print('The 25% of max MP of the Team  : ' +str(b.MP_mean.max()*0.25))
    print(cc)
    print('The mean FGA of the Team  : ' +str(b.FGA_mean.mean()))
    print('The max FGA of the Team  : ' +str(b.FGA_mean.max()))
    print('The median FGA of the Team  : ' +str(b.FGA_mean.median()))
    print('The min FGA of the Team  : ' +str(b.FGA_mean.min()))
    print('The 75% of max FGA of the Team  : ' +str(b.FGA_mean.max()*0.75))
    print('The 50% of max FGA of the Team  : ' +str(b.FGA_mean.max()*0.50))
    print('The 25% of max FGA of the Team  : ' +str(b.FGA_mean.max()*0.25))
    print(cc)
    print('The mean ThreeP_R_mean of the Team  : ' +str(b.ThreeP_R_mean.mean()))
    print('The max ThreeP_R_mean of the Team  : ' +str(b.ThreeP_R_mean.max()))
    print('The median ThreeP_R_mean of the Team  : ' +str(b.ThreeP_R_mean.median()))
    print('The min ThreeP_R_mean of the Team  : ' +str(b.ThreeP_R_mean.min()))
    print('The 75% of max ThreeP_R_mean of the Team  : ' +str(b.ThreeP_R_mean.max()*0.75))
    print('The 50% of max ThreeP_R_mean of the Team  : ' +str(b.ThreeP_R_mean.max()*0.50))
    print('The 25% of max ThreeP_R_mean of the Team  : ' +str(b.ThreeP_R_mean.max()*0.25))
    print(cc)
    print('The mean PTS of the Team  : ' +str(b.PTS.mean()))
    print('The max PTS of the Team  : ' +str(b.PTS.max()))
    print('The median PTS of the Team  : ' +str(b.PTS.median()))
    print('The min PTS of the Team  : ' +str(b.PTS.min()))
    print('The 75% of max PTS of the Team  : ' +str(b.PTS.max()*0.75))
    print('The 50% of max PTS of the Team  : ' +str(b.PTS.max()*0.50))
    print('The 25% of max PTS of the Team  : ' +str(b.PTS.max()*0.25))
    print(cc)
    print('The mean Team_Score of the Team  : ' +str(b.Team_Score.mean()))
    print('The max Team_Score of the Team  : ' +str(b.Team_Score.max()))
    print('The median Team_Score of the Team  : ' +str(b.Team_Score.median()))
    print('The min Team_Score of the Team  : ' +str(b.Team_Score.min()))
    print('The 75% of max Team_Score of the Team  : ' +str(b.Team_Score.max()*0.75))
    print('The 50% of max Team_Score of the Team  : ' +str(b.Team_Score.max()*0.50))
    print('The 25% of max Team_Score of the Team  : ' +str(b.Team_Score.max()*0.25))
    print(cc)
    print('The number of Players in the Team : ' +str(b.Name.count()))
    print(bb)

# %%
merged_drop_dups.head(2)
merged_drop_dups.dtypes

# %%
 
display = merged_drop_dups[(merged_drop_dups['Team']== 'Sacramento Kings')]
display.head(20)

# %%
# Scoring based on Salary

def Compute_Sal(data):
    Team = data[0]
    Salary = data[1]
    
    grp = merged_drop_dups.groupby('Team')
    for name,group in grp:
        Sal_Mean = group.Salary.mean()
        Sal_Max  = group.Salary.max()
        Sal_Min  = group.Salary.min()
        Sal_Max_80 = group.Salary.max()*0.80
        Sal_Max_70 = group.Salary.max()*0.70
        Sal_Max_50 = group.Salary.max()*0.50
        
    
    
        if Team == 'Atlanta Hawks':
            if Salary > Sal_Max_80:
                    
                return 10
            elif Salary > Sal_Max_70 and Salary > Sal_Mean:
                return 7.5
            elif Salary > Sal_Max_50 and Salary > Sal_Mean:
                return 6
            elif Salary > Sal_Mean and Salary < Sal_Max_50:
                return 5
            elif Salary < Sal_Mean and Salary > Sal_Min:
                return 3
            else:
                return 2
        
        
        if Team == 'Boston Celtics':
            if Salary > Sal_Max_80:
                    
                return 10
            elif Salary > Sal_Max_70 and Salary > Sal_Mean:
                return 7.5
            elif Salary > Sal_Max_50 and Salary > Sal_Mean:
                return 6
            elif Salary > Sal_Mean and Salary < Sal_Max_50:
                return 5
            elif Salary < Sal_Mean and Salary > Sal_Min:
                return 3
            else:
                return 2
            
        
        
        if Team == 'Brooklyn Nets':
            if Salary > Sal_Max_80:
                    
                return 10
            elif Salary > Sal_Max_70 and Salary > Sal_Mean:
                return 7.5
            elif Salary > Sal_Max_50 and Salary > Sal_Mean:
                return 6
            elif Salary > Sal_Mean and Salary < Sal_Max_50:
                return 5
            elif Salary < Sal_Mean and Salary > Sal_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Charlotte Hornets':        
            if Salary > Sal_Max_80:
                    
                return 10
            elif Salary > Sal_Max_70 and Salary > Sal_Mean:
                return 7.5
            elif Salary > Sal_Max_50 and Salary > Sal_Mean:
                return 6
            elif Salary > Sal_Mean and Salary < Sal_Max_50:
                return 5
            elif Salary < Sal_Mean and Salary > Sal_Min:
                return 3
            else:
                return 2
            
        
        if Team == 'Chicago Bulls':
            if Salary > Sal_Max_80:
                    
                return 10
            elif Salary > Sal_Max_70 and Salary > Sal_Mean:
                return 7.5
            elif Salary > Sal_Max_50 and Salary > Sal_Mean:
                return 6
            elif Salary > Sal_Mean and Salary < Sal_Max_50:
                return 5
            elif Salary < Sal_Mean and Salary > Sal_Min:
                return 3
            else:
                return 2
            
        
        if Team == 'Cleveland Cavaliers':
            if Salary > Sal_Max_80:
                    
                return 10
            elif Salary > Sal_Max_70 and Salary > Sal_Mean:
                return 7.5
            elif Salary > Sal_Max_50 and Salary > Sal_Mean:
                return 6
            elif Salary > Sal_Mean and Salary < Sal_Max_50:
                return 5
            elif Salary < Sal_Mean and Salary > Sal_Min:
                return 3
            else:
                return 2
            
        
        if Team == 'Dallas Mavericks':
            if Salary > Sal_Max_80:
                    
                return 10
            elif Salary > Sal_Max_70 and Salary > Sal_Mean:
                return 7.5
            elif Salary > Sal_Max_50 and Salary > Sal_Mean:
                return 6
            elif Salary > Sal_Mean and Salary < Sal_Max_50:
                return 5
            elif Salary < Sal_Mean and Salary > Sal_Min:
                return 3
            else:
                return 2
            
        
        
        if Team == 'Denver Nuggets':
            if Salary > Sal_Max_80:
                    
                return 10
            elif Salary > Sal_Max_70 and Salary > Sal_Mean:
                return 7.5
            elif Salary > Sal_Max_50 and Salary > Sal_Mean:
                return 6
            elif Salary > Sal_Mean and Salary < Sal_Max_50:
                return 5
            elif Salary < Sal_Mean and Salary > Sal_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Detroit Pistons':
            if Salary > Sal_Max_80:
                    
                return 10
            elif Salary > Sal_Max_70 and Salary > Sal_Mean:
                return 7.5
            elif Salary > Sal_Max_50 and Salary > Sal_Mean:
                return 6
            elif Salary > Sal_Mean and Salary < Sal_Max_50:
                return 5
            elif Salary < Sal_Mean and Salary > Sal_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Golden State Warrior':
            if Salary > Sal_Max_80:
                    
                return 10
            elif Salary > Sal_Max_70 and Salary > Sal_Mean:
                return 7.5
            elif Salary > Sal_Max_50 and Salary > Sal_Mean:
                return 6
            elif Salary > Sal_Mean and Salary < Sal_Max_50:
                return 5
            elif Salary < Sal_Mean and Salary > Sal_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Houston Rockets':
            if Salary > Sal_Max_80:
                    
                return 10
            elif Salary > Sal_Max_70 and Salary > Sal_Mean:
                return 7.5
            elif Salary > Sal_Max_50 and Salary > Sal_Mean:
                return 6
            elif Salary > Sal_Mean and Salary < Sal_Max_50:
                return 5
            elif Salary < Sal_Mean and Salary > Sal_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Indiana Pacers':
            if Salary > Sal_Max_80:
                    
                return 10
            elif Salary > Sal_Max_70 and Salary > Sal_Mean:
                return 7.5
            elif Salary > Sal_Max_50 and Salary > Sal_Mean:
                return 6
            elif Salary > Sal_Mean and Salary < Sal_Max_50:
                return 5
            elif Salary < Sal_Mean and Salary > Sal_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Los Angeles Clippers':
            if Salary > Sal_Max_80:
                    
                return 10
            elif Salary > Sal_Max_70 and Salary > Sal_Mean:
                return 7.5
            elif Salary > Sal_Max_50 and Salary > Sal_Mean:
                return 6
            elif Salary > Sal_Mean and Salary < Sal_Max_50:
                return 5
            elif Salary < Sal_Mean and Salary > Sal_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Los Angeles Lakers':
            if Salary > Sal_Max_80:
                    
                return 10
            elif Salary > Sal_Max_70 and Salary > Sal_Mean:
                return 7.5
            elif Salary > Sal_Max_50 and Salary > Sal_Mean:
                return 6
            elif Salary > Sal_Mean and Salary < Sal_Max_50:
                return 5
            elif Salary < Sal_Mean and Salary > Sal_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Memphis Grizzlies':   
            if Salary > Sal_Max_80:
                    
                return 10
            elif Salary > Sal_Max_70 and Salary > Sal_Mean:
                return 7.5
            elif Salary > Sal_Max_50 and Salary > Sal_Mean:
                return 6
            elif Salary > Sal_Mean and Salary < Sal_Max_50:
                return 5
            elif Salary < Sal_Mean and Salary > Sal_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Miami Heat':
            if Salary > Sal_Max_80:
                    
                return 10
            elif Salary > Sal_Max_70 and Salary > Sal_Mean:
                return 7.5
            elif Salary > Sal_Max_50 and Salary > Sal_Mean:
                return 6
            elif Salary > Sal_Mean and Salary < Sal_Max_50:
                return 5
            elif Salary < Sal_Mean and Salary > Sal_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Milwaukee Bucks':
            if Salary > Sal_Max_80:
                    
                return 10
            elif Salary > Sal_Max_70 and Salary > Sal_Mean:
                return 7.5
            elif Salary > Sal_Max_50 and Salary > Sal_Mean:
                return 6
            elif Salary > Sal_Mean and Salary < Sal_Max_50:
                return 5
            elif Salary < Sal_Mean and Salary > Sal_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Minnesota Timberwolves':   
            if Salary > Sal_Max_80:
                    
                return 10
            elif Salary > Sal_Max_70 and Salary > Sal_Mean:
                return 7.5
            elif Salary > Sal_Max_50 and Salary > Sal_Mean:
                return 6
            elif Salary > Sal_Mean and Salary < Sal_Max_50:
                return 5
            elif Salary < Sal_Mean and Salary > Sal_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'New Orleans Pelicans':
            if Salary > Sal_Max_80:
                    
                return 10
            elif Salary > Sal_Max_70 and Salary > Sal_Mean:
                return 7.5
            elif Salary > Sal_Max_50 and Salary > Sal_Mean:
                return 6
            elif Salary > Sal_Mean and Salary < Sal_Max_50:
                return 5
            elif Salary < Sal_Mean and Salary > Sal_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'New York Knicks':
            if Salary > Sal_Max_80:
                    
                return 10
            elif Salary > Sal_Max_70 and Salary > Sal_Mean:
                return 7.5
            elif Salary > Sal_Max_50 and Salary > Sal_Mean:
                return 6
            elif Salary > Sal_Mean and Salary < Sal_Max_50:
                return 5
            elif Salary < Sal_Mean and Salary > Sal_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Oklahoma City Thunder':
            if Salary > Sal_Max_80:
                    
                return 10
            elif Salary > Sal_Max_70 and Salary > Sal_Mean:
                return 7.5
            elif Salary > Sal_Max_50 and Salary > Sal_Mean:
                return 6
            elif Salary > Sal_Mean and Salary < Sal_Max_50:
                return 5
            elif Salary < Sal_Mean and Salary > Sal_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Orlando Magic':
            if Salary > Sal_Max_80:
                    
                return 10
            elif Salary > Sal_Max_70 and Salary > Sal_Mean:
                return 7.5
            elif Salary > Sal_Max_50 and Salary > Sal_Mean:
                return 6
            elif Salary > Sal_Mean and Salary < Sal_Max_50:
                return 5
            elif Salary < Sal_Mean and Salary > Sal_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Philadelphia 76ers':
            if Salary > Sal_Max_80:
                    
                return 10
            elif Salary > Sal_Max_70 and Salary > Sal_Mean:
                return 7.5
            elif Salary > Sal_Max_50 and Salary > Sal_Mean:
                return 6
            elif Salary > Sal_Mean and Salary < Sal_Max_50:
                return 5
            elif Salary < Sal_Mean and Salary > Sal_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Phoenix Suns':
            if Salary > Sal_Max_80:
                    
                return 10
            elif Salary > Sal_Max_70 and Salary > Sal_Mean:
                return 7.5
            elif Salary > Sal_Max_50 and Salary > Sal_Mean:
                return 6
            elif Salary > Sal_Mean and Salary < Sal_Max_50:
                return 5
            elif Salary < Sal_Mean and Salary > Sal_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Portland Trail Blazers':
            if Salary > Sal_Max_80:
                    
                return 10
            elif Salary > Sal_Max_70 and Salary > Sal_Mean:
                return 7.5
            elif Salary > Sal_Max_50 and Salary > Sal_Mean:
                return 6
            elif Salary > Sal_Mean and Salary < Sal_Max_50:
                return 5
            elif Salary < Sal_Mean and Salary > Sal_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Sacramento Kings':
            if Salary > Sal_Max_80:
                    
                return 10
            elif Salary > Sal_Max_70 and Salary > Sal_Mean:
                return 7.5
            elif Salary > Sal_Max_50 and Salary > Sal_Mean:
                return 6
            elif Salary > Sal_Mean and Salary < Sal_Max_50:
                return 5
            elif Salary < Sal_Mean and Salary > Sal_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'SAN ANTONIO':
            if Salary > Sal_Max_80:
                    
                return 10
            elif Salary > Sal_Max_70 and Salary > Sal_Mean:
                return 7.5
            elif Salary > Sal_Max_50 and Salary > Sal_Mean:
                return 6
            elif Salary > Sal_Mean and Salary < Sal_Max_50:
                return 5
            elif Salary < Sal_Mean and Salary > Sal_Min:
                return 3
            else:
                return 2
            
            
            
        
        if Team == 'Toronto Raptors':
            if Salary > Sal_Max_80:
                    
                return 10
            elif Salary > Sal_Max_70 and Salary > Sal_Mean:
                return 7.5
            elif Salary > Sal_Max_50 and Salary > Sal_Mean:
                return 6
            elif Salary > Sal_Mean and Salary < Sal_Max_50:
                return 5
            elif Salary < Sal_Mean and Salary > Sal_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Utah Jazz':
            if Salary > Sal_Max_80:
                    
                return 10
            elif Salary > Sal_Max_70 and Salary > Sal_Mean:
                return 7.5
            elif Salary > Sal_Max_50 and Salary > Sal_Mean:
                return 6
            elif Salary > Sal_Mean and Salary < Sal_Max_50:
                return 5
            elif Salary < Sal_Mean and Salary > Sal_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Washington Wizards':
            if Salary > Sal_Max_80:
                    
                return 10
            elif Salary > Sal_Max_70 and Salary > Sal_Mean:
                return 7.5
            elif Salary > Sal_Max_50 and Salary > Sal_Mean:
                return 6
            elif Salary > Sal_Mean and Salary < Sal_Max_50:
                return 5
            elif Salary < Sal_Mean and Salary > Sal_Min:
                return 3
            else:
                return 2
    
    
      
         
    else:
        return 9999999

# %%
#merged_drop_dups.sort_values('Salary', axis=0, ascending=False,inplace=True)

# %%
merged_drop_dups['Salary_Eval'] = merged_drop_dups[['Team','Salary']].apply(Compute_Sal,axis=1)
merged_drop_dups.Salary_Eval.value_counts()

# %%
# Scoring based on Experience

def Compute_Exp(data):
    Team = data[0]
    Exp_mean = data[1]
    
    grp = merged_drop_dups.groupby('Team')
    for name,group in grp:
        Exp_Mean = group.Exp_mean.mean()
        Exp_Max  = group.Exp_mean.max()
        Exp_Min  = group.Exp_mean.min()
        Exp_Max_80 = group.Exp_mean.max()*0.80
        Exp_Max_70 = group.Exp_mean.max()*0.70
        Exp_Max_50 = group.Exp_mean.max()*0.50
        
    
    
        if Team == 'Atlanta Hawks':
            if Exp_mean > Exp_Max_80:
                    
                return 10
            elif Exp_mean > Exp_Max_70 and Exp_mean > Exp_Mean:
                return 7.5
            elif Exp_mean > Exp_Max_50 and Exp_mean > Exp_Mean:
                return 6
            elif Exp_mean > Exp_Mean and Exp_mean < Exp_Max_50:
                return 5
            elif Exp_mean < Exp_Mean and Exp_mean > Exp_Min:
                return 3
            else:
                return 2
        
        
        if Team == 'Boston Celtics':
            if Exp_mean > Exp_Max_80:
                    
                return 10
            elif Exp_mean > Exp_Max_70 and Exp_mean > Exp_Mean:
                return 7.5
            elif Exp_mean > Exp_Max_50 and Exp_mean > Exp_Mean:
                return 6
            elif Exp_mean > Exp_Mean and Exp_mean < Exp_Max_50:
                return 5
            elif Exp_mean < Exp_Mean and Exp_mean > Exp_Min:
                return 3
            else:
                return 2
            
        
        
        if Team == 'Brooklyn Nets':
            if Exp_mean > Exp_Max_80:
                    
                return 10
            elif Exp_mean > Exp_Max_70 and Exp_mean > Exp_Mean:
                return 7.5
            elif Exp_mean > Exp_Max_50 and Exp_mean > Exp_Mean:
                return 6
            elif Exp_mean > Exp_Mean and Exp_mean < Exp_Max_50:
                return 5
            elif Exp_mean < Exp_Mean and Exp_mean > Exp_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Charlotte Hornets':        
            if Exp_mean > Exp_Max_80:
                    
                return 10
            elif Exp_mean > Exp_Max_70 and Exp_mean > Exp_Mean:
                return 7.5
            elif Exp_mean > Exp_Max_50 and Exp_mean > Exp_Mean:
                return 6
            elif Exp_mean > Exp_Mean and Exp_mean < Exp_Max_50:
                return 5
            elif Exp_mean < Exp_Mean and Exp_mean > Exp_Min:
                return 3
            else:
                return 2
            
        
        if Team == 'Chicago Bulls':
            if Exp_mean > Exp_Max_80:
                    
                return 10
            elif Exp_mean > Exp_Max_70 and Exp_mean > Exp_Mean:
                return 7.5
            elif Exp_mean > Exp_Max_50 and Exp_mean > Exp_Mean:
                return 6
            elif Exp_mean > Exp_Mean and Exp_mean < Exp_Max_50:
                return 5
            elif Exp_mean < Exp_Mean and Exp_mean > Exp_Min:
                return 3
            else:
                return 2
            
        
        if Team == 'Cleveland Cavaliers':
            if Exp_mean > Exp_Max_80:
                    
                return 10
            elif Exp_mean > Exp_Max_70 and Exp_mean > Exp_Mean:
                return 7.5
            elif Exp_mean > Exp_Max_50 and Exp_mean > Exp_Mean:
                return 6
            elif Exp_mean > Exp_Mean and Exp_mean < Exp_Max_50:
                return 5
            elif Exp_mean < Exp_Mean and Exp_mean > Exp_Min:
                return 3
            else:
                return 2
            
        
        if Team == 'Dallas Mavericks':
            if Exp_mean > Exp_Max_80:
                    
                return 10
            elif Exp_mean > Exp_Max_70 and Exp_mean > Exp_Mean:
                return 7.5
            elif Exp_mean > Exp_Max_50 and Exp_mean > Exp_Mean:
                return 6
            elif Exp_mean > Exp_Mean and Exp_mean < Exp_Max_50:
                return 5
            elif Exp_mean < Exp_Mean and Exp_mean > Exp_Min:
                return 3
            else:
                return 2
            
        
        
        if Team == 'Denver Nuggets':
            if Exp_mean > Exp_Max_80:
                    
                return 10
            elif Exp_mean > Exp_Max_70 and Exp_mean > Exp_Mean:
                return 7.5
            elif Exp_mean > Exp_Max_50 and Exp_mean > Exp_Mean:
                return 6
            elif Exp_mean > Exp_Mean and Exp_mean < Exp_Max_50:
                return 5
            elif Exp_mean < Exp_Mean and Exp_mean > Exp_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Detroit Pistons':
            if Exp_mean > Exp_Max_80:
                    
                return 10
            elif Exp_mean > Exp_Max_70 and Exp_mean > Exp_Mean:
                return 7.5
            elif Exp_mean > Exp_Max_50 and Exp_mean > Exp_Mean:
                return 6
            elif Exp_mean > Exp_Mean and Exp_mean < Exp_Max_50:
                return 5
            elif Exp_mean < Exp_Mean and Exp_mean > Exp_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Golden State Warrior':
            if Exp_mean > Exp_Max_80:
                    
                return 10
            elif Exp_mean > Exp_Max_70 and Exp_mean > Exp_Mean:
                return 7.5
            elif Exp_mean > Exp_Max_50 and Exp_mean > Exp_Mean:
                return 6
            elif Exp_mean > Exp_Mean and Exp_mean < Exp_Max_50:
                return 5
            elif Exp_mean < Exp_Mean and Exp_mean > Exp_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Houston Rockets':
            if Exp_mean > Exp_Max_80:
                    
                return 10
            elif Exp_mean > Exp_Max_70 and Exp_mean > Exp_Mean:
                return 7.5
            elif Exp_mean > Exp_Max_50 and Exp_mean > Exp_Mean:
                return 6
            elif Exp_mean > Exp_Mean and Exp_mean < Exp_Max_50:
                return 5
            elif Exp_mean < Exp_Mean and Exp_mean > Exp_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Indiana Pacers':
            if Exp_mean > Exp_Max_80:
                    
                return 10
            elif Exp_mean > Exp_Max_70 and Exp_mean > Exp_Mean:
                return 7.5
            elif Exp_mean > Exp_Max_50 and Exp_mean > Exp_Mean:
                return 6
            elif Exp_mean > Exp_Mean and Exp_mean < Exp_Max_50:
                return 5
            elif Exp_mean < Exp_Mean and Exp_mean > Exp_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Los Angeles Clippers':
            if Exp_mean > Exp_Max_80:
                    
                return 10
            elif Exp_mean > Exp_Max_70 and Exp_mean > Exp_Mean:
                return 7.5
            elif Exp_mean > Exp_Max_50 and Exp_mean > Exp_Mean:
                return 6
            elif Exp_mean > Exp_Mean and Exp_mean < Exp_Max_50:
                return 5
            elif Exp_mean < Exp_Mean and Exp_mean > Exp_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Los Angeles Lakers':
            if Exp_mean > Exp_Max_80:
                    
                return 10
            elif Exp_mean > Exp_Max_70 and Exp_mean > Exp_Mean:
                return 7.5
            elif Exp_mean > Exp_Max_50 and Exp_mean > Exp_Mean:
                return 6
            elif Exp_mean > Exp_Mean and Exp_mean < Exp_Max_50:
                return 5
            elif Exp_mean < Exp_Mean and Exp_mean > Exp_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Memphis Grizzlies':   
            if Exp_mean > Exp_Max_80:
                    
                return 10
            elif Exp_mean > Exp_Max_70 and Exp_mean > Exp_Mean:
                return 7.5
            elif Exp_mean > Exp_Max_50 and Exp_mean > Exp_Mean:
                return 6
            elif Exp_mean > Exp_Mean and Exp_mean < Exp_Max_50:
                return 5
            elif Exp_mean < Exp_Mean and Exp_mean > Exp_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Miami Heat':
            if Exp_mean > Exp_Max_80:
                    
                return 10
            elif Exp_mean > Exp_Max_70 and Exp_mean > Exp_Mean:
                return 7.5
            elif Exp_mean > Exp_Max_50 and Exp_mean > Exp_Mean:
                return 6
            elif Exp_mean > Exp_Mean and Exp_mean < Exp_Max_50:
                return 5
            elif Exp_mean < Exp_Mean and Exp_mean > Exp_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Milwaukee Bucks':
            if Exp_mean > Exp_Max_80:
                    
                return 10
            elif Exp_mean > Exp_Max_70 and Exp_mean > Exp_Mean:
                return 7.5
            elif Exp_mean > Exp_Max_50 and Exp_mean > Exp_Mean:
                return 6
            elif Exp_mean > Exp_Mean and Exp_mean < Exp_Max_50:
                return 5
            elif Exp_mean < Exp_Mean and Exp_mean > Exp_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Minnesota Timberwolves':   
            if Exp_mean > Exp_Max_80:
                    
                return 10
            elif Exp_mean > Exp_Max_70 and Exp_mean > Exp_Mean:
                return 7.5
            elif Exp_mean > Exp_Max_50 and Exp_mean > Exp_Mean:
                return 6
            elif Exp_mean > Exp_Mean and Exp_mean < Exp_Max_50:
                return 5
            elif Exp_mean < Exp_Mean and Exp_mean > Exp_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'New Orleans Pelicans':
            if Exp_mean > Exp_Max_80:
                    
                return 10
            elif Exp_mean > Exp_Max_70 and Exp_mean > Exp_Mean:
                return 7.5
            elif Exp_mean > Exp_Max_50 and Exp_mean > Exp_Mean:
                return 6
            elif Exp_mean > Exp_Mean and Exp_mean < Exp_Max_50:
                return 5
            elif Exp_mean < Exp_Mean and Exp_mean > Exp_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'New York Knicks':
            if Exp_mean > Exp_Max_80:
                    
                return 10
            elif Exp_mean > Exp_Max_70 and Exp_mean > Exp_Mean:
                return 7.5
            elif Exp_mean > Exp_Max_50 and Exp_mean > Exp_Mean:
                return 6
            elif Exp_mean > Exp_Mean and Exp_mean < Exp_Max_50:
                return 5
            elif Exp_mean < Exp_Mean and Exp_mean > Exp_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Oklahoma City Thunder':
            if Exp_mean > Exp_Max_80:
                    
                return 10
            elif Exp_mean > Exp_Max_70 and Exp_mean > Exp_Mean:
                return 7.5
            elif Exp_mean > Exp_Max_50 and Exp_mean > Exp_Mean:
                return 6
            elif Exp_mean > Exp_Mean and Exp_mean < Exp_Max_50:
                return 5
            elif Exp_mean < Exp_Mean and Exp_mean > Exp_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Orlando Magic':
            if Exp_mean > Exp_Max_80:
                    
                return 10
            elif Exp_mean > Exp_Max_70 and Exp_mean > Exp_Mean:
                return 7.5
            elif Exp_mean > Exp_Max_50 and Exp_mean > Exp_Mean:
                return 6
            elif Exp_mean > Exp_Mean and Exp_mean < Exp_Max_50:
                return 5
            elif Exp_mean < Exp_Mean and Exp_mean > Exp_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Philadelphia 76ers':
            if Exp_mean > Exp_Max_80:
                    
                return 10
            elif Exp_mean > Exp_Max_70 and Exp_mean > Exp_Mean:
                return 7.5
            elif Exp_mean > Exp_Max_50 and Exp_mean > Exp_Mean:
                return 6
            elif Exp_mean > Exp_Mean and Exp_mean < Exp_Max_50:
                return 5
            elif Exp_mean < Exp_Mean and Exp_mean > Exp_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Phoenix Suns':
            if Exp_mean > Exp_Max_80:
                    
                return 10
            elif Exp_mean > Exp_Max_70 and Exp_mean > Exp_Mean:
                return 7.5
            elif Exp_mean > Exp_Max_50 and Exp_mean > Exp_Mean:
                return 6
            elif Exp_mean > Exp_Mean and Exp_mean < Exp_Max_50:
                return 5
            elif Exp_mean < Exp_Mean and Exp_mean > Exp_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Portland Trail Blazers':
            if Exp_mean > Exp_Max_80:
                    
                return 10
            elif Exp_mean > Exp_Max_70 and Exp_mean > Exp_Mean:
                return 7.5
            elif Exp_mean > Exp_Max_50 and Exp_mean > Exp_Mean:
                return 6
            elif Exp_mean > Exp_Mean and Exp_mean < Exp_Max_50:
                return 5
            elif Exp_mean < Exp_Mean and Exp_mean > Exp_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Sacramento Kings':
            if Exp_mean > Exp_Max_80:
                    
                return 10
            elif Exp_mean > Exp_Max_70 and Exp_mean > Exp_Mean:
                return 7.5
            elif Exp_mean > Exp_Max_50 and Exp_mean > Exp_Mean:
                return 6
            elif Exp_mean > Exp_Mean and Exp_mean < Exp_Max_50:
                return 5
            elif Exp_mean < Exp_Mean and Exp_mean > Exp_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'SAN ANTONIO':
            if Exp_mean > Exp_Max_80:
                    
                return 10
            elif Exp_mean > Exp_Max_70 and Exp_mean > Exp_Mean:
                return 7.5
            elif Exp_mean > Exp_Max_50 and Exp_mean > Exp_Mean:
                return 6
            elif Exp_mean > Exp_Mean and Exp_mean < Exp_Max_50:
                return 5
            elif Exp_mean < Exp_Mean and Exp_mean > Exp_Min:
                return 3
            else:
                return 2
            
            
            
        
        if Team == 'Toronto Raptors':
            if Exp_mean > Exp_Max_80:
                    
                return 10
            elif Exp_mean > Exp_Max_70 and Exp_mean > Exp_Mean:
                return 7.5
            elif Exp_mean > Exp_Max_50 and Exp_mean > Exp_Mean:
                return 6
            elif Exp_mean > Exp_Mean and Exp_mean < Exp_Max_50:
                return 5
            elif Exp_mean < Exp_Mean and Exp_mean > Exp_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Utah Jazz':
            if Exp_mean > Exp_Max_80:
                    
                return 10
            elif Exp_mean > Exp_Max_70 and Exp_mean > Exp_Mean:
                return 7.5
            elif Exp_mean > Exp_Max_50 and Exp_mean > Exp_Mean:
                return 6
            elif Exp_mean > Exp_Mean and Exp_mean < Exp_Max_50:
                return 5
            elif Exp_mean < Exp_Mean and Exp_mean > Exp_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Washington Wizards':
            if Exp_mean > Exp_Max_80:
                    
                return 10
            elif Exp_mean > Exp_Max_70 and Exp_mean > Exp_Mean:
                return 7.5
            elif Exp_mean > Exp_Max_50 and Exp_mean > Exp_Mean:
                return 6
            elif Exp_mean > Exp_Mean and Exp_mean < Exp_Max_50:
                return 5
            elif Exp_mean < Exp_Mean and Exp_mean > Exp_Min:
                return 3
            else:
                return 2
    
    
      
         
    else:
        return 9999999

# %%
merged_drop_dups['Exp_Eval'] = merged_drop_dups[['Team','Exp_mean']].apply(Compute_Exp,axis=1)
merged_drop_dups.Exp_Eval.value_counts()

# %%
merged_drop_dups.head(100)

# %%
# Scoring based on Experience

def Compute_G(data):
    Team = data[0]
    G_mean = data[1]
    
    grp = merged_drop_dups.groupby('Team')
    for name,group in grp:
        G_Mean = group.G_mean.mean()
        G_Max  = group.G_mean.max()
        G_Min  = group.G_mean.min()
        G_Max_80 = group.G_mean.max()*0.80
        G_Max_70 = group.G_mean.max()*0.70
        G_Max_50 = group.G_mean.max()*0.50
        
    
    
        if Team == 'Atlanta Hawks':
            if G_mean > G_Max_80:
                    
                return 10
            elif G_mean > G_Max_70 and G_mean > G_Mean:
                return 7.5
            elif G_mean > G_Max_50 and G_mean > G_Mean:
                return 6
            elif G_mean > G_Mean and G_mean < G_Max_50:
                return 5
            elif G_mean < G_Mean and G_mean > G_Min:
                return 3
            else:
                return 2
        
        
        if Team == 'Boston Celtics':
            if G_mean > G_Max_80:
                    
                return 10
            elif G_mean > G_Max_70 and G_mean > G_Mean:
                return 7.5
            elif G_mean > G_Max_50 and G_mean > G_Mean:
                return 6
            elif G_mean > G_Mean and G_mean < G_Max_50:
                return 5
            elif G_mean < G_Mean and G_mean > G_Min:
                return 3
            else:
                return 2
            
        
        
        if Team == 'Brooklyn Nets':
            if G_mean > G_Max_80:
                    
                return 10
            elif G_mean > G_Max_70 and G_mean > G_Mean:
                return 7.5
            elif G_mean > G_Max_50 and G_mean > G_Mean:
                return 6
            elif G_mean > G_Mean and G_mean < G_Max_50:
                return 5
            elif G_mean < G_Mean and G_mean > G_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Charlotte Hornets':        
            if G_mean > G_Max_80:
                    
                return 10
            elif G_mean > G_Max_70 and G_mean > G_Mean:
                return 7.5
            elif G_mean > G_Max_50 and G_mean > G_Mean:
                return 6
            elif G_mean > G_Mean and G_mean < G_Max_50:
                return 5
            elif G_mean < G_Mean and G_mean > G_Min:
                return 3
            else:
                return 2
            
        
        if Team == 'Chicago Bulls':
            if G_mean > G_Max_80:
                    
                return 10
            elif G_mean > G_Max_70 and G_mean > G_Mean:
                return 7.5
            elif G_mean > G_Max_50 and G_mean > G_Mean:
                return 6
            elif G_mean > G_Mean and G_mean < G_Max_50:
                return 5
            elif G_mean < G_Mean and G_mean > G_Min:
                return 3
            else:
                return 2
            
        
        if Team == 'Cleveland Cavaliers':
            if G_mean > G_Max_80:
                    
                return 10
            elif G_mean > G_Max_70 and G_mean > G_Mean:
                return 7.5
            elif G_mean > G_Max_50 and G_mean > G_Mean:
                return 6
            elif G_mean > G_Mean and G_mean < G_Max_50:
                return 5
            elif G_mean < G_Mean and G_mean > G_Min:
                return 3
            else:
                return 2
            
        
        if Team == 'Dallas Mavericks':
            if G_mean > G_Max_80:
                    
                return 10
            elif G_mean > G_Max_70 and G_mean > G_Mean:
                return 7.5
            elif G_mean > G_Max_50 and G_mean > G_Mean:
                return 6
            elif G_mean > G_Mean and G_mean < G_Max_50:
                return 5
            elif G_mean < G_Mean and G_mean > G_Min:
                return 3
            else:
                return 2
            
        
        
        if Team == 'Denver Nuggets':
            if G_mean > G_Max_80:
                    
                return 10
            elif G_mean > G_Max_70 and G_mean > G_Mean:
                return 7.5
            elif G_mean > G_Max_50 and G_mean > G_Mean:
                return 6
            elif G_mean > G_Mean and G_mean < G_Max_50:
                return 5
            elif G_mean < G_Mean and G_mean > G_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Detroit Pistons':
            if G_mean > G_Max_80:
                    
                return 10
            elif G_mean > G_Max_70 and G_mean > G_Mean:
                return 7.5
            elif G_mean > G_Max_50 and G_mean > G_Mean:
                return 6
            elif G_mean > G_Mean and G_mean < G_Max_50:
                return 5
            elif G_mean < G_Mean and G_mean > G_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Golden State Warrior':
            if G_mean > G_Max_80:
                    
                return 10
            elif G_mean > G_Max_70 and G_mean > G_Mean:
                return 7.5
            elif G_mean > G_Max_50 and G_mean > G_Mean:
                return 6
            elif G_mean > G_Mean and G_mean < G_Max_50:
                return 5
            elif G_mean < G_Mean and G_mean > G_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Houston Rockets':
            if G_mean > G_Max_80:
                    
                return 10
            elif G_mean > G_Max_70 and G_mean > G_Mean:
                return 7.5
            elif G_mean > G_Max_50 and G_mean > G_Mean:
                return 6
            elif G_mean > G_Mean and G_mean < G_Max_50:
                return 5
            elif G_mean < G_Mean and G_mean > G_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Indiana Pacers':
            if G_mean > G_Max_80:
                    
                return 10
            elif G_mean > G_Max_70 and G_mean > G_Mean:
                return 7.5
            elif G_mean > G_Max_50 and G_mean > G_Mean:
                return 6
            elif G_mean > G_Mean and G_mean < G_Max_50:
                return 5
            elif G_mean < G_Mean and G_mean > G_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Los Angeles Clippers':
            if G_mean > G_Max_80:
                    
                return 10
            elif G_mean > G_Max_70 and G_mean > G_Mean:
                return 7.5
            elif G_mean > G_Max_50 and G_mean > G_Mean:
                return 6
            elif G_mean > G_Mean and G_mean < G_Max_50:
                return 5
            elif G_mean < G_Mean and G_mean > G_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Los Angeles Lakers':
            if G_mean > G_Max_80:
                    
                return 10
            elif G_mean > G_Max_70 and G_mean > G_Mean:
                return 7.5
            elif G_mean > G_Max_50 and G_mean > G_Mean:
                return 6
            elif G_mean > G_Mean and G_mean < G_Max_50:
                return 5
            elif G_mean < G_Mean and G_mean > G_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Memphis Grizzlies':   
            if G_mean > G_Max_80:
                    
                return 10
            elif G_mean > G_Max_70 and G_mean > G_Mean:
                return 7.5
            elif G_mean > G_Max_50 and G_mean > G_Mean:
                return 6
            elif G_mean > G_Mean and G_mean < G_Max_50:
                return 5
            elif G_mean < G_Mean and G_mean > G_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Miami Heat':
            if G_mean > G_Max_80:
                    
                return 10
            elif G_mean > G_Max_70 and G_mean > G_Mean:
                return 7.5
            elif G_mean > G_Max_50 and G_mean > G_Mean:
                return 6
            elif G_mean > G_Mean and G_mean < G_Max_50:
                return 5
            elif G_mean < G_Mean and G_mean > G_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Milwaukee Bucks':
            if G_mean > G_Max_80:
                    
                return 10
            elif G_mean > G_Max_70 and G_mean > G_Mean:
                return 7.5
            elif G_mean > G_Max_50 and G_mean > G_Mean:
                return 6
            elif G_mean > G_Mean and G_mean < G_Max_50:
                return 5
            elif G_mean < G_Mean and G_mean > G_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Minnesota Timberwolves':   
            if G_mean > G_Max_80:
                    
                return 10
            elif G_mean > G_Max_70 and G_mean > G_Mean:
                return 7.5
            elif G_mean > G_Max_50 and G_mean > G_Mean:
                return 6
            elif G_mean > G_Mean and G_mean < G_Max_50:
                return 5
            elif G_mean < G_Mean and G_mean > G_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'New Orleans Pelicans':
            if G_mean > G_Max_80:
                    
                return 10
            elif G_mean > G_Max_70 and G_mean > G_Mean:
                return 7.5
            elif G_mean > G_Max_50 and G_mean > G_Mean:
                return 6
            elif G_mean > G_Mean and G_mean < G_Max_50:
                return 5
            elif G_mean < G_Mean and G_mean > G_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'New York Knicks':
            if G_mean > G_Max_80:
                    
                return 10
            elif G_mean > G_Max_70 and G_mean > G_Mean:
                return 7.5
            elif G_mean > G_Max_50 and G_mean > G_Mean:
                return 6
            elif G_mean > G_Mean and G_mean < G_Max_50:
                return 5
            elif G_mean < G_Mean and G_mean > G_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Oklahoma City Thunder':
            if G_mean > G_Max_80:
                    
                return 10
            elif G_mean > G_Max_70 and G_mean > G_Mean:
                return 7.5
            elif G_mean > G_Max_50 and G_mean > G_Mean:
                return 6
            elif G_mean > G_Mean and G_mean < G_Max_50:
                return 5
            elif G_mean < G_Mean and G_mean > G_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Orlando Magic':
            if G_mean > G_Max_80:
                    
                return 10
            elif G_mean > G_Max_70 and G_mean > G_Mean:
                return 7.5
            elif G_mean > G_Max_50 and G_mean > G_Mean:
                return 6
            elif G_mean > G_Mean and G_mean < G_Max_50:
                return 5
            elif G_mean < G_Mean and G_mean > G_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Philadelphia 76ers':
            if G_mean > G_Max_80:
                    
                return 10
            elif G_mean > G_Max_70 and G_mean > G_Mean:
                return 7.5
            elif G_mean > G_Max_50 and G_mean > G_Mean:
                return 6
            elif G_mean > G_Mean and G_mean < G_Max_50:
                return 5
            elif G_mean < G_Mean and G_mean > G_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Phoenix Suns':
            if G_mean > G_Max_80:
                    
                return 10
            elif G_mean > G_Max_70 and G_mean > G_Mean:
                return 7.5
            elif G_mean > G_Max_50 and G_mean > G_Mean:
                return 6
            elif G_mean > G_Mean and G_mean < G_Max_50:
                return 5
            elif G_mean < G_Mean and G_mean > G_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Portland Trail Blazers':
            if G_mean > G_Max_80:
                    
                return 10
            elif G_mean > G_Max_70 and G_mean > G_Mean:
                return 7.5
            elif G_mean > G_Max_50 and G_mean > G_Mean:
                return 6
            elif G_mean > G_Mean and G_mean < G_Max_50:
                return 5
            elif G_mean < G_Mean and G_mean > G_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Sacramento Kings':
            if G_mean > G_Max_80:
                    
                return 10
            elif G_mean > G_Max_70 and G_mean > G_Mean:
                return 7.5
            elif G_mean > G_Max_50 and G_mean > G_Mean:
                return 6
            elif G_mean > G_Mean and G_mean < G_Max_50:
                return 5
            elif G_mean < G_Mean and G_mean > G_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'SAN ANTONIO':
            if G_mean > G_Max_80:
                    
                return 10
            elif G_mean > G_Max_70 and G_mean > G_Mean:
                return 7.5
            elif G_mean > G_Max_50 and G_mean > G_Mean:
                return 6
            elif G_mean > G_Mean and G_mean < G_Max_50:
                return 5
            elif G_mean < G_Mean and G_mean > G_Min:
                return 3
            else:
                return 2
            
            
            
        
        if Team == 'Toronto Raptors':
            if G_mean > G_Max_80:
                    
                return 10
            elif G_mean > G_Max_70 and G_mean > G_Mean:
                return 7.5
            elif G_mean > G_Max_50 and G_mean > G_Mean:
                return 6
            elif G_mean > G_Mean and G_mean < G_Max_50:
                return 5
            elif G_mean < G_Mean and G_mean > G_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Utah Jazz':
            if G_mean > G_Max_80:
                    
                return 10
            elif G_mean > G_Max_70 and G_mean > G_Mean:
                return 7.5
            elif G_mean > G_Max_50 and G_mean > G_Mean:
                return 6
            elif G_mean > G_Mean and G_mean < G_Max_50:
                return 5
            elif G_mean < G_Mean and G_mean > G_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Washington Wizards':
            if G_mean > G_Max_80:
                    
                return 10
            elif G_mean > G_Max_70 and G_mean > G_Mean:
                return 7.5
            elif G_mean > G_Max_50 and G_mean > G_Mean:
                return 6
            elif G_mean > G_Mean and G_mean < G_Max_50:
                return 5
            elif G_mean < G_Mean and G_mean > G_Min:
                return 3
            else:
                return 2
    
    
      
         
    else:
        return 9999999

# %%
merged_drop_dups['G_Eval'] = merged_drop_dups[['Team','G_mean']].apply(Compute_G,axis=1)
merged_drop_dups.G_Eval.value_counts()

# %%
# Scoring based on GS

def Compute_GS(data):
    Team = data[0]
    GS_mean = data[1]
    
    grp = merged_drop_dups.groupby('Team')
    for name,group in grp:
        GS_Mean = group.GS_mean.mean()
        GS_Max  = group.GS_mean.max()
        GS_Min  = group.GS_mean.min()
        GS_Max_80 = group.GS_mean.max()*0.80
        GS_Max_70 = group.GS_mean.max()*0.70
        GS_Max_50 = group.GS_mean.max()*0.50
        
    
    
        if Team == 'Atlanta Hawks':
            if GS_mean > GS_Max_80:
                    
                return 10
            elif GS_mean > GS_Max_70 and GS_mean > GS_Mean:
                return 7.5
            elif GS_mean > GS_Max_50 and GS_mean > GS_Mean:
                return 6
            elif GS_mean > GS_Mean and GS_mean < GS_Max_50:
                return 5
            elif GS_mean < GS_Mean and GS_mean > GS_Min:
                return 3
            else:
                return 2
        
        
        if Team == 'Boston Celtics':
            if GS_mean > GS_Max_80:
                    
                return 10
            elif GS_mean > GS_Max_70 and GS_mean > GS_Mean:
                return 7.5
            elif GS_mean > GS_Max_50 and GS_mean > GS_Mean:
                return 6
            elif GS_mean > GS_Mean and GS_mean < GS_Max_50:
                return 5
            elif GS_mean < GS_Mean and GS_mean > GS_Min:
                return 3
            else:
                return 2
            
        
        
        if Team == 'Brooklyn Nets':
            if GS_mean > GS_Max_80:
                    
                return 10
            elif GS_mean > GS_Max_70 and GS_mean > GS_Mean:
                return 7.5
            elif GS_mean > GS_Max_50 and GS_mean > GS_Mean:
                return 6
            elif GS_mean > GS_Mean and GS_mean < GS_Max_50:
                return 5
            elif GS_mean < GS_Mean and GS_mean > GS_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Charlotte Hornets':        
            if GS_mean > GS_Max_80:
                    
                return 10
            elif GS_mean > GS_Max_70 and GS_mean > GS_Mean:
                return 7.5
            elif GS_mean > GS_Max_50 and GS_mean > GS_Mean:
                return 6
            elif GS_mean > GS_Mean and GS_mean < GS_Max_50:
                return 5
            elif GS_mean < GS_Mean and GS_mean > GS_Min:
                return 3
            else:
                return 2
            
        
        if Team == 'Chicago Bulls':
            if GS_mean > GS_Max_80:
                    
                return 10
            elif GS_mean > GS_Max_70 and GS_mean > GS_Mean:
                return 7.5
            elif GS_mean > GS_Max_50 and GS_mean > GS_Mean:
                return 6
            elif GS_mean > GS_Mean and GS_mean < GS_Max_50:
                return 5
            elif GS_mean < GS_Mean and GS_mean > GS_Min:
                return 3
            else:
                return 2
            
        
        if Team == 'Cleveland Cavaliers':
            if GS_mean > GS_Max_80:
                    
                return 10
            elif GS_mean > GS_Max_70 and GS_mean > GS_Mean:
                return 7.5
            elif GS_mean > GS_Max_50 and GS_mean > GS_Mean:
                return 6
            elif GS_mean > GS_Mean and GS_mean < GS_Max_50:
                return 5
            elif GS_mean < GS_Mean and GS_mean > GS_Min:
                return 3
            else:
                return 2
            
        
        if Team == 'Dallas Mavericks':
            if GS_mean > GS_Max_80:
                    
                return 10
            elif GS_mean > GS_Max_70 and GS_mean > GS_Mean:
                return 7.5
            elif GS_mean > GS_Max_50 and GS_mean > GS_Mean:
                return 6
            elif GS_mean > GS_Mean and GS_mean < GS_Max_50:
                return 5
            elif GS_mean < GS_Mean and GS_mean > GS_Min:
                return 3
            else:
                return 2
            
        
        
        if Team == 'Denver Nuggets':
            if GS_mean > GS_Max_80:
                    
                return 10
            elif GS_mean > GS_Max_70 and GS_mean > GS_Mean:
                return 7.5
            elif GS_mean > GS_Max_50 and GS_mean > GS_Mean:
                return 6
            elif GS_mean > GS_Mean and GS_mean < GS_Max_50:
                return 5
            elif GS_mean < GS_Mean and GS_mean > GS_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Detroit Pistons':
            if GS_mean > GS_Max_80:
                    
                return 10
            elif GS_mean > GS_Max_70 and GS_mean > GS_Mean:
                return 7.5
            elif GS_mean > GS_Max_50 and GS_mean > GS_Mean:
                return 6
            elif GS_mean > GS_Mean and GS_mean < GS_Max_50:
                return 5
            elif GS_mean < GS_Mean and GS_mean > GS_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Golden State Warrior':
            if GS_mean > GS_Max_80:
                    
                return 10
            elif GS_mean > GS_Max_70 and GS_mean > GS_Mean:
                return 7.5
            elif GS_mean > GS_Max_50 and GS_mean > GS_Mean:
                return 6
            elif GS_mean > GS_Mean and GS_mean < GS_Max_50:
                return 5
            elif GS_mean < GS_Mean and GS_mean > GS_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Houston Rockets':
            if GS_mean > GS_Max_80:
                    
                return 10
            elif GS_mean > GS_Max_70 and GS_mean > GS_Mean:
                return 7.5
            elif GS_mean > GS_Max_50 and GS_mean > GS_Mean:
                return 6
            elif GS_mean > GS_Mean and GS_mean < GS_Max_50:
                return 5
            elif GS_mean < GS_Mean and GS_mean > GS_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Indiana Pacers':
            if GS_mean > GS_Max_80:
                    
                return 10
            elif GS_mean > GS_Max_70 and GS_mean > GS_Mean:
                return 7.5
            elif GS_mean > GS_Max_50 and GS_mean > GS_Mean:
                return 6
            elif GS_mean > GS_Mean and GS_mean < GS_Max_50:
                return 5
            elif GS_mean < GS_Mean and GS_mean > GS_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Los Angeles Clippers':
            if GS_mean > GS_Max_80:
                    
                return 10
            elif GS_mean > GS_Max_70 and GS_mean > GS_Mean:
                return 7.5
            elif GS_mean > GS_Max_50 and GS_mean > GS_Mean:
                return 6
            elif GS_mean > GS_Mean and GS_mean < GS_Max_50:
                return 5
            elif GS_mean < GS_Mean and GS_mean > GS_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Los Angeles Lakers':
            if GS_mean > GS_Max_80:
                    
                return 10
            elif GS_mean > GS_Max_70 and GS_mean > GS_Mean:
                return 7.5
            elif GS_mean > GS_Max_50 and GS_mean > GS_Mean:
                return 6
            elif GS_mean > GS_Mean and GS_mean < GS_Max_50:
                return 5
            elif GS_mean < GS_Mean and GS_mean > GS_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Memphis Grizzlies':   
            if GS_mean > GS_Max_80:
                    
                return 10
            elif GS_mean > GS_Max_70 and GS_mean > GS_Mean:
                return 7.5
            elif GS_mean > GS_Max_50 and GS_mean > GS_Mean:
                return 6
            elif GS_mean > GS_Mean and GS_mean < GS_Max_50:
                return 5
            elif GS_mean < GS_Mean and GS_mean > GS_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Miami Heat':
            if GS_mean > GS_Max_80:
                    
                return 10
            elif GS_mean > GS_Max_70 and GS_mean > GS_Mean:
                return 7.5
            elif GS_mean > GS_Max_50 and GS_mean > GS_Mean:
                return 6
            elif GS_mean > GS_Mean and GS_mean < GS_Max_50:
                return 5
            elif GS_mean < GS_Mean and GS_mean > GS_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Milwaukee Bucks':
            if GS_mean > GS_Max_80:
                    
                return 10
            elif GS_mean > GS_Max_70 and GS_mean > GS_Mean:
                return 7.5
            elif GS_mean > GS_Max_50 and GS_mean > GS_Mean:
                return 6
            elif GS_mean > GS_Mean and GS_mean < GS_Max_50:
                return 5
            elif GS_mean < GS_Mean and GS_mean > GS_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Minnesota Timberwolves':   
            if GS_mean > GS_Max_80:
                    
                return 10
            elif GS_mean > GS_Max_70 and GS_mean > GS_Mean:
                return 7.5
            elif GS_mean > GS_Max_50 and GS_mean > GS_Mean:
                return 6
            elif GS_mean > GS_Mean and GS_mean < GS_Max_50:
                return 5
            elif GS_mean < GS_Mean and GS_mean > GS_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'New Orleans Pelicans':
            if GS_mean > GS_Max_80:
                    
                return 10
            elif GS_mean > GS_Max_70 and GS_mean > GS_Mean:
                return 7.5
            elif GS_mean > GS_Max_50 and GS_mean > GS_Mean:
                return 6
            elif GS_mean > GS_Mean and GS_mean < GS_Max_50:
                return 5
            elif GS_mean < GS_Mean and GS_mean > GS_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'New York Knicks':
            if GS_mean > GS_Max_80:
                    
                return 10
            elif GS_mean > GS_Max_70 and GS_mean > GS_Mean:
                return 7.5
            elif GS_mean > GS_Max_50 and GS_mean > GS_Mean:
                return 6
            elif GS_mean > GS_Mean and GS_mean < GS_Max_50:
                return 5
            elif GS_mean < GS_Mean and GS_mean > GS_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Oklahoma City Thunder':
            if GS_mean > GS_Max_80:
                    
                return 10
            elif GS_mean > GS_Max_70 and GS_mean > GS_Mean:
                return 7.5
            elif GS_mean > GS_Max_50 and GS_mean > GS_Mean:
                return 6
            elif GS_mean > GS_Mean and GS_mean < GS_Max_50:
                return 5
            elif GS_mean < GS_Mean and GS_mean > GS_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Orlando Magic':
            if GS_mean > GS_Max_80:
                    
                return 10
            elif GS_mean > GS_Max_70 and GS_mean > GS_Mean:
                return 7.5
            elif GS_mean > GS_Max_50 and GS_mean > GS_Mean:
                return 6
            elif GS_mean > GS_Mean and GS_mean < GS_Max_50:
                return 5
            elif GS_mean < GS_Mean and GS_mean > GS_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Philadelphia 76ers':
            if GS_mean > GS_Max_80:
                    
                return 10
            elif GS_mean > GS_Max_70 and GS_mean > GS_Mean:
                return 7.5
            elif GS_mean > GS_Max_50 and GS_mean > GS_Mean:
                return 6
            elif GS_mean > GS_Mean and GS_mean < GS_Max_50:
                return 5
            elif GS_mean < GS_Mean and GS_mean > GS_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Phoenix Suns':
            if GS_mean > GS_Max_80:
                    
                return 10
            elif GS_mean > GS_Max_70 and GS_mean > GS_Mean:
                return 7.5
            elif GS_mean > GS_Max_50 and GS_mean > GS_Mean:
                return 6
            elif GS_mean > GS_Mean and GS_mean < GS_Max_50:
                return 5
            elif GS_mean < GS_Mean and GS_mean > GS_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Portland Trail Blazers':
            if GS_mean > GS_Max_80:
                    
                return 10
            elif GS_mean > GS_Max_70 and GS_mean > GS_Mean:
                return 7.5
            elif GS_mean > GS_Max_50 and GS_mean > GS_Mean:
                return 6
            elif GS_mean > GS_Mean and GS_mean < GS_Max_50:
                return 5
            elif GS_mean < GS_Mean and GS_mean > GS_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Sacramento Kings':
            if GS_mean > GS_Max_80:
                    
                return 10
            elif GS_mean > GS_Max_70 and GS_mean > GS_Mean:
                return 7.5
            elif GS_mean > GS_Max_50 and GS_mean > GS_Mean:
                return 6
            elif GS_mean > GS_Mean and GS_mean < GS_Max_50:
                return 5
            elif GS_mean < GS_Mean and GS_mean > GS_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'SAN ANTONIO':
            if GS_mean > GS_Max_80:
                    
                return 10
            elif GS_mean > GS_Max_70 and GS_mean > GS_Mean:
                return 7.5
            elif GS_mean > GS_Max_50 and GS_mean > GS_Mean:
                return 6
            elif GS_mean > GS_Mean and GS_mean < GS_Max_50:
                return 5
            elif GS_mean < GS_Mean and GS_mean > GS_Min:
                return 3
            else:
                return 2
            
            
            
        
        if Team == 'Toronto Raptors':
            if GS_mean > GS_Max_80:
                    
                return 10
            elif GS_mean > GS_Max_70 and GS_mean > GS_Mean:
                return 7.5
            elif GS_mean > GS_Max_50 and GS_mean > GS_Mean:
                return 6
            elif GS_mean > GS_Mean and GS_mean < GS_Max_50:
                return 5
            elif GS_mean < GS_Mean and GS_mean > GS_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Utah Jazz':
            if GS_mean > GS_Max_80:
                    
                return 10
            elif GS_mean > GS_Max_70 and GS_mean > GS_Mean:
                return 7.5
            elif GS_mean > GS_Max_50 and GS_mean > GS_Mean:
                return 6
            elif GS_mean > GS_Mean and GS_mean < GS_Max_50:
                return 5
            elif GS_mean < GS_Mean and GS_mean > GS_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Washington Wizards':
            if GS_mean > GS_Max_80:
                    
                return 10
            elif GS_mean > GS_Max_70 and GS_mean > GS_Mean:
                return 7.5
            elif GS_mean > GS_Max_50 and GS_mean > GS_Mean:
                return 6
            elif GS_mean > GS_Mean and GS_mean < GS_Max_50:
                return 5
            elif GS_mean < GS_Mean and GS_mean > GS_Min:
                return 3
            else:
                return 2
    
    
      
         
    else:
        return 9999999

# %%
merged_drop_dups['GS_Eval'] = merged_drop_dups[['Team','GS_mean']].apply(Compute_GS,axis=1)
merged_drop_dups.GS_Eval.value_counts()

# %%
# Scoring based on MP

def Compute_MP(data):
    Team = data[0]
    MP_mean = data[1]
    
    grp = merged_drop_dups.groupby('Team')
    for name,group in grp:
        MP_Mean = group.MP_mean.mean()
        MP_Max  = group.MP_mean.max()
        MP_Min  = group.MP_mean.min()
        MP_Max_80 = group.MP_mean.max()*0.80
        MP_Max_70 = group.MP_mean.max()*0.70
        MP_Max_50 = group.MP_mean.max()*0.50
        
    
    
        if Team == 'Atlanta Hawks':
            if MP_mean > MP_Max_80:
                    
                return 10
            elif MP_mean > MP_Max_70 and MP_mean > MP_Mean:
                return 7.5
            elif MP_mean > MP_Max_50 and MP_mean > MP_Mean:
                return 6
            elif MP_mean > MP_Mean and MP_mean < MP_Max_50:
                return 5
            elif MP_mean < MP_Mean and MP_mean > MP_Min:
                return 3
            else:
                return 2
        
        
        if Team == 'Boston Celtics':
            if MP_mean > MP_Max_80:
                    
                return 10
            elif MP_mean > MP_Max_70 and MP_mean > MP_Mean:
                return 7.5
            elif MP_mean > MP_Max_50 and MP_mean > MP_Mean:
                return 6
            elif MP_mean > MP_Mean and MP_mean < MP_Max_50:
                return 5
            elif MP_mean < MP_Mean and MP_mean > MP_Min:
                return 3
            else:
                return 2
            
        
        
        if Team == 'Brooklyn Nets':
            if MP_mean > MP_Max_80:
                    
                return 10
            elif MP_mean > MP_Max_70 and MP_mean > MP_Mean:
                return 7.5
            elif MP_mean > MP_Max_50 and MP_mean > MP_Mean:
                return 6
            elif MP_mean > MP_Mean and MP_mean < MP_Max_50:
                return 5
            elif MP_mean < MP_Mean and MP_mean > MP_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Charlotte Hornets':        
            if MP_mean > MP_Max_80:
                    
                return 10
            elif MP_mean > MP_Max_70 and MP_mean > MP_Mean:
                return 7.5
            elif MP_mean > MP_Max_50 and MP_mean > MP_Mean:
                return 6
            elif MP_mean > MP_Mean and MP_mean < MP_Max_50:
                return 5
            elif MP_mean < MP_Mean and MP_mean > MP_Min:
                return 3
            else:
                return 2
            
        
        if Team == 'Chicago Bulls':
            if MP_mean > MP_Max_80:
                    
                return 10
            elif MP_mean > MP_Max_70 and MP_mean > MP_Mean:
                return 7.5
            elif MP_mean > MP_Max_50 and MP_mean > MP_Mean:
                return 6
            elif MP_mean > MP_Mean and MP_mean < MP_Max_50:
                return 5
            elif MP_mean < MP_Mean and MP_mean > MP_Min:
                return 3
            else:
                return 2
            
        
        if Team == 'Cleveland Cavaliers':
            if MP_mean > MP_Max_80:
                    
                return 10
            elif MP_mean > MP_Max_70 and MP_mean > MP_Mean:
                return 7.5
            elif MP_mean > MP_Max_50 and MP_mean > MP_Mean:
                return 6
            elif MP_mean > MP_Mean and MP_mean < MP_Max_50:
                return 5
            elif MP_mean < MP_Mean and MP_mean > MP_Min:
                return 3
            else:
                return 2
            
        
        if Team == 'Dallas Mavericks':
            if MP_mean > MP_Max_80:
                    
                return 10
            elif MP_mean > MP_Max_70 and MP_mean > MP_Mean:
                return 7.5
            elif MP_mean > MP_Max_50 and MP_mean > MP_Mean:
                return 6
            elif MP_mean > MP_Mean and MP_mean < MP_Max_50:
                return 5
            elif MP_mean < MP_Mean and MP_mean > MP_Min:
                return 3
            else:
                return 2
            
        
        
        if Team == 'Denver Nuggets':
            if MP_mean > MP_Max_80:
                    
                return 10
            elif MP_mean > MP_Max_70 and MP_mean > MP_Mean:
                return 7.5
            elif MP_mean > MP_Max_50 and MP_mean > MP_Mean:
                return 6
            elif MP_mean > MP_Mean and MP_mean < MP_Max_50:
                return 5
            elif MP_mean < MP_Mean and MP_mean > MP_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Detroit Pistons':
            if MP_mean > MP_Max_80:
                    
                return 10
            elif MP_mean > MP_Max_70 and MP_mean > MP_Mean:
                return 7.5
            elif MP_mean > MP_Max_50 and MP_mean > MP_Mean:
                return 6
            elif MP_mean > MP_Mean and MP_mean < MP_Max_50:
                return 5
            elif MP_mean < MP_Mean and MP_mean > MP_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Golden State Warrior':
            if MP_mean > MP_Max_80:
                    
                return 10
            elif MP_mean > MP_Max_70 and MP_mean > MP_Mean:
                return 7.5
            elif MP_mean > MP_Max_50 and MP_mean > MP_Mean:
                return 6
            elif MP_mean > MP_Mean and MP_mean < MP_Max_50:
                return 5
            elif MP_mean < MP_Mean and MP_mean > MP_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Houston Rockets':
            if MP_mean > MP_Max_80:
                    
                return 10
            elif MP_mean > MP_Max_70 and MP_mean > MP_Mean:
                return 7.5
            elif MP_mean > MP_Max_50 and MP_mean > MP_Mean:
                return 6
            elif MP_mean > MP_Mean and MP_mean < MP_Max_50:
                return 5
            elif MP_mean < MP_Mean and MP_mean > MP_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Indiana Pacers':
            if MP_mean > MP_Max_80:
                    
                return 10
            elif MP_mean > MP_Max_70 and MP_mean > MP_Mean:
                return 7.5
            elif MP_mean > MP_Max_50 and MP_mean > MP_Mean:
                return 6
            elif MP_mean > MP_Mean and MP_mean < MP_Max_50:
                return 5
            elif MP_mean < MP_Mean and MP_mean > MP_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Los Angeles Clippers':
            if MP_mean > MP_Max_80:
                    
                return 10
            elif MP_mean > MP_Max_70 and MP_mean > MP_Mean:
                return 7.5
            elif MP_mean > MP_Max_50 and MP_mean > MP_Mean:
                return 6
            elif MP_mean > MP_Mean and MP_mean < MP_Max_50:
                return 5
            elif MP_mean < MP_Mean and MP_mean > MP_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Los Angeles Lakers':
            if MP_mean > MP_Max_80:
                    
                return 10
            elif MP_mean > MP_Max_70 and MP_mean > MP_Mean:
                return 7.5
            elif MP_mean > MP_Max_50 and MP_mean > MP_Mean:
                return 6
            elif MP_mean > MP_Mean and MP_mean < MP_Max_50:
                return 5
            elif MP_mean < MP_Mean and MP_mean > MP_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Memphis Grizzlies':   
            if MP_mean > MP_Max_80:
                    
                return 10
            elif MP_mean > MP_Max_70 and MP_mean > MP_Mean:
                return 7.5
            elif MP_mean > MP_Max_50 and MP_mean > MP_Mean:
                return 6
            elif MP_mean > MP_Mean and MP_mean < MP_Max_50:
                return 5
            elif MP_mean < MP_Mean and MP_mean > MP_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Miami Heat':
            if MP_mean > MP_Max_80:
                    
                return 10
            elif MP_mean > MP_Max_70 and MP_mean > MP_Mean:
                return 7.5
            elif MP_mean > MP_Max_50 and MP_mean > MP_Mean:
                return 6
            elif MP_mean > MP_Mean and MP_mean < MP_Max_50:
                return 5
            elif MP_mean < MP_Mean and MP_mean > MP_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Milwaukee Bucks':
            if MP_mean > MP_Max_80:
                    
                return 10
            elif MP_mean > MP_Max_70 and MP_mean > MP_Mean:
                return 7.5
            elif MP_mean > MP_Max_50 and MP_mean > MP_Mean:
                return 6
            elif MP_mean > MP_Mean and MP_mean < MP_Max_50:
                return 5
            elif MP_mean < MP_Mean and MP_mean > MP_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Minnesota Timberwolves':   
            if MP_mean > MP_Max_80:
                    
                return 10
            elif MP_mean > MP_Max_70 and MP_mean > MP_Mean:
                return 7.5
            elif MP_mean > MP_Max_50 and MP_mean > MP_Mean:
                return 6
            elif MP_mean > MP_Mean and MP_mean < MP_Max_50:
                return 5
            elif MP_mean < MP_Mean and MP_mean > MP_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'New Orleans Pelicans':
            if MP_mean > MP_Max_80:
                    
                return 10
            elif MP_mean > MP_Max_70 and MP_mean > MP_Mean:
                return 7.5
            elif MP_mean > MP_Max_50 and MP_mean > MP_Mean:
                return 6
            elif MP_mean > MP_Mean and MP_mean < MP_Max_50:
                return 5
            elif MP_mean < MP_Mean and MP_mean > MP_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'New York Knicks':
            if MP_mean > MP_Max_80:
                    
                return 10
            elif MP_mean > MP_Max_70 and MP_mean > MP_Mean:
                return 7.5
            elif MP_mean > MP_Max_50 and MP_mean > MP_Mean:
                return 6
            elif MP_mean > MP_Mean and MP_mean < MP_Max_50:
                return 5
            elif MP_mean < MP_Mean and MP_mean > MP_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Oklahoma City Thunder':
            if MP_mean > MP_Max_80:
                    
                return 10
            elif MP_mean > MP_Max_70 and MP_mean > MP_Mean:
                return 7.5
            elif MP_mean > MP_Max_50 and MP_mean > MP_Mean:
                return 6
            elif MP_mean > MP_Mean and MP_mean < MP_Max_50:
                return 5
            elif MP_mean < MP_Mean and MP_mean > MP_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Orlando Magic':
            if MP_mean > MP_Max_80:
                    
                return 10
            elif MP_mean > MP_Max_70 and MP_mean > MP_Mean:
                return 7.5
            elif MP_mean > MP_Max_50 and MP_mean > MP_Mean:
                return 6
            elif MP_mean > MP_Mean and MP_mean < MP_Max_50:
                return 5
            elif MP_mean < MP_Mean and MP_mean > MP_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Philadelphia 76ers':
            if MP_mean > MP_Max_80:
                    
                return 10
            elif MP_mean > MP_Max_70 and MP_mean > MP_Mean:
                return 7.5
            elif MP_mean > MP_Max_50 and MP_mean > MP_Mean:
                return 6
            elif MP_mean > MP_Mean and MP_mean < MP_Max_50:
                return 5
            elif MP_mean < MP_Mean and MP_mean > MP_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Phoenix Suns':
            if MP_mean > MP_Max_80:
                    
                return 10
            elif MP_mean > MP_Max_70 and MP_mean > MP_Mean:
                return 7.5
            elif MP_mean > MP_Max_50 and MP_mean > MP_Mean:
                return 6
            elif MP_mean > MP_Mean and MP_mean < MP_Max_50:
                return 5
            elif MP_mean < MP_Mean and MP_mean > MP_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Portland Trail Blazers':
            if MP_mean > MP_Max_80:
                    
                return 10
            elif MP_mean > MP_Max_70 and MP_mean > MP_Mean:
                return 7.5
            elif MP_mean > MP_Max_50 and MP_mean > MP_Mean:
                return 6
            elif MP_mean > MP_Mean and MP_mean < MP_Max_50:
                return 5
            elif MP_mean < MP_Mean and MP_mean > MP_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Sacramento Kings':
            if MP_mean > MP_Max_80:
                    
                return 10
            elif MP_mean > MP_Max_70 and MP_mean > MP_Mean:
                return 7.5
            elif MP_mean > MP_Max_50 and MP_mean > MP_Mean:
                return 6
            elif MP_mean > MP_Mean and MP_mean < MP_Max_50:
                return 5
            elif MP_mean < MP_Mean and MP_mean > MP_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'SAN ANTONIO':
            if MP_mean > MP_Max_80:
                    
                return 10
            elif MP_mean > MP_Max_70 and MP_mean > MP_Mean:
                return 7.5
            elif MP_mean > MP_Max_50 and MP_mean > MP_Mean:
                return 6
            elif MP_mean > MP_Mean and MP_mean < MP_Max_50:
                return 5
            elif MP_mean < MP_Mean and MP_mean > MP_Min:
                return 3
            else:
                return 2
            
            
            
        
        if Team == 'Toronto Raptors':
            if MP_mean > MP_Max_80:
                    
                return 10
            elif MP_mean > MP_Max_70 and MP_mean > MP_Mean:
                return 7.5
            elif MP_mean > MP_Max_50 and MP_mean > MP_Mean:
                return 6
            elif MP_mean > MP_Mean and MP_mean < MP_Max_50:
                return 5
            elif MP_mean < MP_Mean and MP_mean > MP_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Utah Jazz':
            if MP_mean > MP_Max_80:
                    
                return 10
            elif MP_mean > MP_Max_70 and MP_mean > MP_Mean:
                return 7.5
            elif MP_mean > MP_Max_50 and MP_mean > MP_Mean:
                return 6
            elif MP_mean > MP_Mean and MP_mean < MP_Max_50:
                return 5
            elif MP_mean < MP_Mean and MP_mean > MP_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Washington Wizards':
            if MP_mean > MP_Max_80:
                    
                return 10
            elif MP_mean > MP_Max_70 and MP_mean > MP_Mean:
                return 7.5
            elif MP_mean > MP_Max_50 and MP_mean > MP_Mean:
                return 6
            elif MP_mean > MP_Mean and MP_mean < MP_Max_50:
                return 5
            elif MP_mean < MP_Mean and MP_mean > MP_Min:
                return 3
            else:
                return 2
    
    
      
         
    else:
        return 1

# %%
merged_drop_dups['MP_Eval'] = merged_drop_dups[['Team','MP_mean']].apply(Compute_MP,axis=1)
merged_drop_dups.MP_Eval.value_counts()

# %%
# Scoring based on FGA

def Compute_FGA(data):
    Team = data[0]
    FGA_mean = data[1]
    
    grp = merged_drop_dups.groupby('Team')
    for name,group in grp:
        FGA_Mean = group.FGA_mean.mean()
        FGA_Max  = group.FGA_mean.max()
        FGA_Min  = group.FGA_mean.min()
        FGA_Max_80 = group.FGA_mean.max()*0.80
        FGA_Max_70 = group.FGA_mean.max()*0.70
        FGA_Max_50 = group.FGA_mean.max()*0.50
        
    
    
        if Team == 'Atlanta Hawks':
            if FGA_mean > FGA_Max_80:
                    
                return 10
            elif FGA_mean > FGA_Max_70 and FGA_mean > FGA_Mean:
                return 7.5
            elif FGA_mean > FGA_Max_50 and FGA_mean > FGA_Mean:
                return 6
            elif FGA_mean > FGA_Mean and FGA_mean < FGA_Max_50:
                return 5
            elif FGA_mean < FGA_Mean and FGA_mean > FGA_Min:
                return 3
            else:
                return 2
        
        
        if Team == 'Boston Celtics':
            if FGA_mean > FGA_Max_80:
                    
                return 10
            elif FGA_mean > FGA_Max_70 and FGA_mean > FGA_Mean:
                return 7.5
            elif FGA_mean > FGA_Max_50 and FGA_mean > FGA_Mean:
                return 6
            elif FGA_mean > FGA_Mean and FGA_mean < FGA_Max_50:
                return 5
            elif FGA_mean < FGA_Mean and FGA_mean > FGA_Min:
                return 3
            else:
                return 2
            
        
        
        if Team == 'Brooklyn Nets':
            if FGA_mean > FGA_Max_80:
                    
                return 10
            elif FGA_mean > FGA_Max_70 and FGA_mean > FGA_Mean:
                return 7.5
            elif FGA_mean > FGA_Max_50 and FGA_mean > FGA_Mean:
                return 6
            elif FGA_mean > FGA_Mean and FGA_mean < FGA_Max_50:
                return 5
            elif FGA_mean < FGA_Mean and FGA_mean > FGA_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Charlotte Hornets':        
            if FGA_mean > FGA_Max_80:
                    
                return 10
            elif FGA_mean > FGA_Max_70 and FGA_mean > FGA_Mean:
                return 7.5
            elif FGA_mean > FGA_Max_50 and FGA_mean > FGA_Mean:
                return 6
            elif FGA_mean > FGA_Mean and FGA_mean < FGA_Max_50:
                return 5
            elif FGA_mean < FGA_Mean and FGA_mean > FGA_Min:
                return 3
            else:
                return 2
            
        
        if Team == 'Chicago Bulls':
            if FGA_mean > FGA_Max_80:
                    
                return 10
            elif FGA_mean > FGA_Max_70 and FGA_mean > FGA_Mean:
                return 7.5
            elif FGA_mean > FGA_Max_50 and FGA_mean > FGA_Mean:
                return 6
            elif FGA_mean > FGA_Mean and FGA_mean < FGA_Max_50:
                return 5
            elif FGA_mean < FGA_Mean and FGA_mean > FGA_Min:
                return 3
            else:
                return 2
            
        
        if Team == 'Cleveland Cavaliers':
            if FGA_mean > FGA_Max_80:
                    
                return 10
            elif FGA_mean > FGA_Max_70 and FGA_mean > FGA_Mean:
                return 7.5
            elif FGA_mean > FGA_Max_50 and FGA_mean > FGA_Mean:
                return 6
            elif FGA_mean > FGA_Mean and FGA_mean < FGA_Max_50:
                return 5
            elif FGA_mean < FGA_Mean and FGA_mean > FGA_Min:
                return 3
            else:
                return 2
            
        
        if Team == 'Dallas Mavericks':
            if FGA_mean > FGA_Max_80:
                    
                return 10
            elif FGA_mean > FGA_Max_70 and FGA_mean > FGA_Mean:
                return 7.5
            elif FGA_mean > FGA_Max_50 and FGA_mean > FGA_Mean:
                return 6
            elif FGA_mean > FGA_Mean and FGA_mean < FGA_Max_50:
                return 5
            elif FGA_mean < FGA_Mean and FGA_mean > FGA_Min:
                return 3
            else:
                return 2
            
        
        
        if Team == 'Denver Nuggets':
            if FGA_mean > FGA_Max_80:
                    
                return 10
            elif FGA_mean > FGA_Max_70 and FGA_mean > FGA_Mean:
                return 7.5
            elif FGA_mean > FGA_Max_50 and FGA_mean > FGA_Mean:
                return 6
            elif FGA_mean > FGA_Mean and FGA_mean < FGA_Max_50:
                return 5
            elif FGA_mean < FGA_Mean and FGA_mean > FGA_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Detroit Pistons':
            if FGA_mean > FGA_Max_80:
                    
                return 10
            elif FGA_mean > FGA_Max_70 and FGA_mean > FGA_Mean:
                return 7.5
            elif FGA_mean > FGA_Max_50 and FGA_mean > FGA_Mean:
                return 6
            elif FGA_mean > FGA_Mean and FGA_mean < FGA_Max_50:
                return 5
            elif FGA_mean < FGA_Mean and FGA_mean > FGA_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Golden State Warrior':
            if FGA_mean > FGA_Max_80:
                    
                return 10
            elif FGA_mean > FGA_Max_70 and FGA_mean > FGA_Mean:
                return 7.5
            elif FGA_mean > FGA_Max_50 and FGA_mean > FGA_Mean:
                return 6
            elif FGA_mean > FGA_Mean and FGA_mean < FGA_Max_50:
                return 5
            elif FGA_mean < FGA_Mean and FGA_mean > FGA_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Houston Rockets':
            if FGA_mean > FGA_Max_80:
                    
                return 10
            elif FGA_mean > FGA_Max_70 and FGA_mean > FGA_Mean:
                return 7.5
            elif FGA_mean > FGA_Max_50 and FGA_mean > FGA_Mean:
                return 6
            elif FGA_mean > FGA_Mean and FGA_mean < FGA_Max_50:
                return 5
            elif FGA_mean < FGA_Mean and FGA_mean > FGA_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Indiana Pacers':
            if FGA_mean > FGA_Max_80:
                    
                return 10
            elif FGA_mean > FGA_Max_70 and FGA_mean > FGA_Mean:
                return 7.5
            elif FGA_mean > FGA_Max_50 and FGA_mean > FGA_Mean:
                return 6
            elif FGA_mean > FGA_Mean and FGA_mean < FGA_Max_50:
                return 5
            elif FGA_mean < FGA_Mean and FGA_mean > FGA_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Los Angeles Clippers':
            if FGA_mean > FGA_Max_80:
                    
                return 10
            elif FGA_mean > FGA_Max_70 and FGA_mean > FGA_Mean:
                return 7.5
            elif FGA_mean > FGA_Max_50 and FGA_mean > FGA_Mean:
                return 6
            elif FGA_mean > FGA_Mean and FGA_mean < FGA_Max_50:
                return 5
            elif FGA_mean < FGA_Mean and FGA_mean > FGA_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Los Angeles Lakers':
            if FGA_mean > FGA_Max_80:
                    
                return 10
            elif FGA_mean > FGA_Max_70 and FGA_mean > FGA_Mean:
                return 7.5
            elif FGA_mean > FGA_Max_50 and FGA_mean > FGA_Mean:
                return 6
            elif FGA_mean > FGA_Mean and FGA_mean < FGA_Max_50:
                return 5
            elif FGA_mean < FGA_Mean and FGA_mean > FGA_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Memphis Grizzlies':   
            if FGA_mean > FGA_Max_80:
                    
                return 10
            elif FGA_mean > FGA_Max_70 and FGA_mean > FGA_Mean:
                return 7.5
            elif FGA_mean > FGA_Max_50 and FGA_mean > FGA_Mean:
                return 6
            elif FGA_mean > FGA_Mean and FGA_mean < FGA_Max_50:
                return 5
            elif FGA_mean < FGA_Mean and FGA_mean > FGA_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Miami Heat':
            if FGA_mean > FGA_Max_80:
                    
                return 10
            elif FGA_mean > FGA_Max_70 and FGA_mean > FGA_Mean:
                return 7.5
            elif FGA_mean > FGA_Max_50 and FGA_mean > FGA_Mean:
                return 6
            elif FGA_mean > FGA_Mean and FGA_mean < FGA_Max_50:
                return 5
            elif FGA_mean < FGA_Mean and FGA_mean > FGA_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Milwaukee Bucks':
            if FGA_mean > FGA_Max_80:
                    
                return 10
            elif FGA_mean > FGA_Max_70 and FGA_mean > FGA_Mean:
                return 7.5
            elif FGA_mean > FGA_Max_50 and FGA_mean > FGA_Mean:
                return 6
            elif FGA_mean > FGA_Mean and FGA_mean < FGA_Max_50:
                return 5
            elif FGA_mean < FGA_Mean and FGA_mean > FGA_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Minnesota Timberwolves':   
            if FGA_mean > FGA_Max_80:
                    
                return 10
            elif FGA_mean > FGA_Max_70 and FGA_mean > FGA_Mean:
                return 7.5
            elif FGA_mean > FGA_Max_50 and FGA_mean > FGA_Mean:
                return 6
            elif FGA_mean > FGA_Mean and FGA_mean < FGA_Max_50:
                return 5
            elif FGA_mean < FGA_Mean and FGA_mean > FGA_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'New Orleans Pelicans':
            if FGA_mean > FGA_Max_80:
                    
                return 10
            elif FGA_mean > FGA_Max_70 and FGA_mean > FGA_Mean:
                return 7.5
            elif FGA_mean > FGA_Max_50 and FGA_mean > FGA_Mean:
                return 6
            elif FGA_mean > FGA_Mean and FGA_mean < FGA_Max_50:
                return 5
            elif FGA_mean < FGA_Mean and FGA_mean > FGA_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'New York Knicks':
            if FGA_mean > FGA_Max_80:
                    
                return 10
            elif FGA_mean > FGA_Max_70 and FGA_mean > FGA_Mean:
                return 7.5
            elif FGA_mean > FGA_Max_50 and FGA_mean > FGA_Mean:
                return 6
            elif FGA_mean > FGA_Mean and FGA_mean < FGA_Max_50:
                return 5
            elif FGA_mean < FGA_Mean and FGA_mean > FGA_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Oklahoma City Thunder':
            if FGA_mean > FGA_Max_80:
                    
                return 10
            elif FGA_mean > FGA_Max_70 and FGA_mean > FGA_Mean:
                return 7.5
            elif FGA_mean > FGA_Max_50 and FGA_mean > FGA_Mean:
                return 6
            elif FGA_mean > FGA_Mean and FGA_mean < FGA_Max_50:
                return 5
            elif FGA_mean < FGA_Mean and FGA_mean > FGA_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Orlando Magic':
            if FGA_mean > FGA_Max_80:
                    
                return 10
            elif FGA_mean > FGA_Max_70 and FGA_mean > FGA_Mean:
                return 7.5
            elif FGA_mean > FGA_Max_50 and FGA_mean > FGA_Mean:
                return 6
            elif FGA_mean > FGA_Mean and FGA_mean < FGA_Max_50:
                return 5
            elif FGA_mean < FGA_Mean and FGA_mean > FGA_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Philadelphia 76ers':
            if FGA_mean > FGA_Max_80:
                    
                return 10
            elif FGA_mean > FGA_Max_70 and FGA_mean > FGA_Mean:
                return 7.5
            elif FGA_mean > FGA_Max_50 and FGA_mean > FGA_Mean:
                return 6
            elif FGA_mean > FGA_Mean and FGA_mean < FGA_Max_50:
                return 5
            elif FGA_mean < FGA_Mean and FGA_mean > FGA_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Phoenix Suns':
            if FGA_mean > FGA_Max_80:
                    
                return 10
            elif FGA_mean > FGA_Max_70 and FGA_mean > FGA_Mean:
                return 7.5
            elif FGA_mean > FGA_Max_50 and FGA_mean > FGA_Mean:
                return 6
            elif FGA_mean > FGA_Mean and FGA_mean < FGA_Max_50:
                return 5
            elif FGA_mean < FGA_Mean and FGA_mean > FGA_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Portland Trail Blazers':
            if FGA_mean > FGA_Max_80:
                    
                return 10
            elif FGA_mean > FGA_Max_70 and FGA_mean > FGA_Mean:
                return 7.5
            elif FGA_mean > FGA_Max_50 and FGA_mean > FGA_Mean:
                return 6
            elif FGA_mean > FGA_Mean and FGA_mean < FGA_Max_50:
                return 5
            elif FGA_mean < FGA_Mean and FGA_mean > FGA_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Sacramento Kings':
            if FGA_mean > FGA_Max_80:
                    
                return 10
            elif FGA_mean > FGA_Max_70 and FGA_mean > FGA_Mean:
                return 7.5
            elif FGA_mean > FGA_Max_50 and FGA_mean > FGA_Mean:
                return 6
            elif FGA_mean > FGA_Mean and FGA_mean < FGA_Max_50:
                return 5
            elif FGA_mean < FGA_Mean and FGA_mean > FGA_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'SAN ANTONIO':
            if FGA_mean > FGA_Max_80:
                    
                return 10
            elif FGA_mean > FGA_Max_70 and FGA_mean > FGA_Mean:
                return 7.5
            elif FGA_mean > FGA_Max_50 and FGA_mean > FGA_Mean:
                return 6
            elif FGA_mean > FGA_Mean and FGA_mean < FGA_Max_50:
                return 5
            elif FGA_mean < FGA_Mean and FGA_mean > FGA_Min:
                return 3
            else:
                return 2
            
            
            
        
        if Team == 'Toronto Raptors':
            if FGA_mean > FGA_Max_80:
                    
                return 10
            elif FGA_mean > FGA_Max_70 and FGA_mean > FGA_Mean:
                return 7.5
            elif FGA_mean > FGA_Max_50 and FGA_mean > FGA_Mean:
                return 6
            elif FGA_mean > FGA_Mean and FGA_mean < FGA_Max_50:
                return 5
            elif FGA_mean < FGA_Mean and FGA_mean > FGA_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Utah Jazz':
            if FGA_mean > FGA_Max_80:
                    
                return 10
            elif FGA_mean > FGA_Max_70 and FGA_mean > FGA_Mean:
                return 7.5
            elif FGA_mean > FGA_Max_50 and FGA_mean > FGA_Mean:
                return 6
            elif FGA_mean > FGA_Mean and FGA_mean < FGA_Max_50:
                return 5
            elif FGA_mean < FGA_Mean and FGA_mean > FGA_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Washington Wizards':
            if FGA_mean > FGA_Max_80:
                    
                return 10
            elif FGA_mean > FGA_Max_70 and FGA_mean > FGA_Mean:
                return 7.5
            elif FGA_mean > FGA_Max_50 and FGA_mean > FGA_Mean:
                return 6
            elif FGA_mean > FGA_Mean and FGA_mean < FGA_Max_50:
                return 5
            elif FGA_mean < FGA_Mean and FGA_mean > FGA_Min:
                return 3
            else:
                return 2
    
    
      
         
    else:
        return 1

# %%
merged_drop_dups['FGA_Eval'] = merged_drop_dups[['Team','FGA_mean']].apply(Compute_FGA,axis=1)

merged_drop_dups.FGA_Eval.value_counts()

# %%
# Scoring based on FGA

def Compute_ThreeP_R(data):
    Team = data[0]
    ThreeP_R_mean = data[1]
    
    grp = merged_drop_dups.groupby('Team')
    for name,group in grp:
        ThreeP_R_Mean = group.ThreeP_R_mean.mean()
        ThreeP_R_Max  = group.ThreeP_R_mean.max()
        ThreeP_R_Min  = group.ThreeP_R_mean.min()
        ThreeP_R_Max_80 = group.ThreeP_R_mean.max()*0.80
        ThreeP_R_Max_70 = group.ThreeP_R_mean.max()*0.70
        ThreeP_R_Max_50 = group.ThreeP_R_mean.max()*0.50
        
    
    
        if Team == 'Atlanta Hawks':
            if ThreeP_R_mean > ThreeP_R_Max_80:
                    
                return 10
            elif ThreeP_R_mean > ThreeP_R_Max_70 and ThreeP_R_mean > ThreeP_R_Mean:
                return 7.5
            elif ThreeP_R_mean > ThreeP_R_Max_50 and ThreeP_R_mean > ThreeP_R_Mean:
                return 6
            elif ThreeP_R_mean > ThreeP_R_Mean and ThreeP_R_mean < ThreeP_R_Max_50:
                return 5
            elif ThreeP_R_mean < ThreeP_R_Mean and ThreeP_R_mean > ThreeP_R_Min:
                return 3
            else:
                return 2
        
        
        if Team == 'Boston Celtics':
            if ThreeP_R_mean > ThreeP_R_Max_80:
                    
                return 10
            elif ThreeP_R_mean > ThreeP_R_Max_70 and ThreeP_R_mean > ThreeP_R_Mean:
                return 7.5
            elif ThreeP_R_mean > ThreeP_R_Max_50 and ThreeP_R_mean > ThreeP_R_Mean:
                return 6
            elif ThreeP_R_mean > ThreeP_R_Mean and ThreeP_R_mean < ThreeP_R_Max_50:
                return 5
            elif ThreeP_R_mean < ThreeP_R_Mean and ThreeP_R_mean > ThreeP_R_Min:
                return 3
            else:
                return 2
            
        
        
        if Team == 'Brooklyn Nets':
            if ThreeP_R_mean > ThreeP_R_Max_80:
                    
                return 10
            elif ThreeP_R_mean > ThreeP_R_Max_70 and ThreeP_R_mean > ThreeP_R_Mean:
                return 7.5
            elif ThreeP_R_mean > ThreeP_R_Max_50 and ThreeP_R_mean > ThreeP_R_Mean:
                return 6
            elif ThreeP_R_mean > ThreeP_R_Mean and ThreeP_R_mean < ThreeP_R_Max_50:
                return 5
            elif ThreeP_R_mean < ThreeP_R_Mean and ThreeP_R_mean > ThreeP_R_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Charlotte Hornets':        
            if ThreeP_R_mean > ThreeP_R_Max_80:
                    
                return 10
            elif ThreeP_R_mean > ThreeP_R_Max_70 and ThreeP_R_mean > ThreeP_R_Mean:
                return 7.5
            elif ThreeP_R_mean > ThreeP_R_Max_50 and ThreeP_R_mean > ThreeP_R_Mean:
                return 6
            elif ThreeP_R_mean > ThreeP_R_Mean and ThreeP_R_mean < ThreeP_R_Max_50:
                return 5
            elif ThreeP_R_mean < ThreeP_R_Mean and ThreeP_R_mean > ThreeP_R_Min:
                return 3
            else:
                return 2
            
        
        if Team == 'Chicago Bulls':
            if ThreeP_R_mean > ThreeP_R_Max_80:
                    
                return 10
            elif ThreeP_R_mean > ThreeP_R_Max_70 and ThreeP_R_mean > ThreeP_R_Mean:
                return 7.5
            elif ThreeP_R_mean > ThreeP_R_Max_50 and ThreeP_R_mean > ThreeP_R_Mean:
                return 6
            elif ThreeP_R_mean > ThreeP_R_Mean and ThreeP_R_mean < ThreeP_R_Max_50:
                return 5
            elif ThreeP_R_mean < ThreeP_R_Mean and ThreeP_R_mean > ThreeP_R_Min:
                return 3
            else:
                return 2
            
        
        if Team == 'Cleveland Cavaliers':
            if ThreeP_R_mean > ThreeP_R_Max_80:
                    
                return 10
            elif ThreeP_R_mean > ThreeP_R_Max_70 and ThreeP_R_mean > ThreeP_R_Mean:
                return 7.5
            elif ThreeP_R_mean > ThreeP_R_Max_50 and ThreeP_R_mean > ThreeP_R_Mean:
                return 6
            elif ThreeP_R_mean > ThreeP_R_Mean and ThreeP_R_mean < ThreeP_R_Max_50:
                return 5
            elif ThreeP_R_mean < ThreeP_R_Mean and ThreeP_R_mean > ThreeP_R_Min:
                return 3
            else:
                return 2
            
        
        if Team == 'Dallas Mavericks':
            if ThreeP_R_mean > ThreeP_R_Max_80:
                    
                return 10
            elif ThreeP_R_mean > ThreeP_R_Max_70 and ThreeP_R_mean > ThreeP_R_Mean:
                return 7.5
            elif ThreeP_R_mean > ThreeP_R_Max_50 and ThreeP_R_mean > ThreeP_R_Mean:
                return 6
            elif ThreeP_R_mean > ThreeP_R_Mean and ThreeP_R_mean < ThreeP_R_Max_50:
                return 5
            elif ThreeP_R_mean < ThreeP_R_Mean and ThreeP_R_mean > ThreeP_R_Min:
                return 3
            else:
                return 2
            
        
        
        if Team == 'Denver Nuggets':
            if ThreeP_R_mean > ThreeP_R_Max_80:
                    
                return 10
            elif ThreeP_R_mean > ThreeP_R_Max_70 and ThreeP_R_mean > ThreeP_R_Mean:
                return 7.5
            elif ThreeP_R_mean > ThreeP_R_Max_50 and ThreeP_R_mean > ThreeP_R_Mean:
                return 6
            elif ThreeP_R_mean > ThreeP_R_Mean and ThreeP_R_mean < ThreeP_R_Max_50:
                return 5
            elif ThreeP_R_mean < ThreeP_R_Mean and ThreeP_R_mean > ThreeP_R_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Detroit Pistons':
            if ThreeP_R_mean > ThreeP_R_Max_80:
                    
                return 10
            elif ThreeP_R_mean > ThreeP_R_Max_70 and ThreeP_R_mean > ThreeP_R_Mean:
                return 7.5
            elif ThreeP_R_mean > ThreeP_R_Max_50 and ThreeP_R_mean > ThreeP_R_Mean:
                return 6
            elif ThreeP_R_mean > ThreeP_R_Mean and ThreeP_R_mean < ThreeP_R_Max_50:
                return 5
            elif ThreeP_R_mean < ThreeP_R_Mean and ThreeP_R_mean > ThreeP_R_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Golden State Warrior':
            if ThreeP_R_mean > ThreeP_R_Max_80:
                    
                return 10
            elif ThreeP_R_mean > ThreeP_R_Max_70 and ThreeP_R_mean > ThreeP_R_Mean:
                return 7.5
            elif ThreeP_R_mean > ThreeP_R_Max_50 and ThreeP_R_mean > ThreeP_R_Mean:
                return 6
            elif ThreeP_R_mean > ThreeP_R_Mean and ThreeP_R_mean < ThreeP_R_Max_50:
                return 5
            elif ThreeP_R_mean < ThreeP_R_Mean and ThreeP_R_mean > ThreeP_R_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Houston Rockets':
            if ThreeP_R_mean > ThreeP_R_Max_80:
                    
                return 10
            elif ThreeP_R_mean > ThreeP_R_Max_70 and ThreeP_R_mean > ThreeP_R_Mean:
                return 7.5
            elif ThreeP_R_mean > ThreeP_R_Max_50 and ThreeP_R_mean > ThreeP_R_Mean:
                return 6
            elif ThreeP_R_mean > ThreeP_R_Mean and ThreeP_R_mean < ThreeP_R_Max_50:
                return 5
            elif ThreeP_R_mean < ThreeP_R_Mean and ThreeP_R_mean > ThreeP_R_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Indiana Pacers':
            if ThreeP_R_mean > ThreeP_R_Max_80:
                    
                return 10
            elif ThreeP_R_mean > ThreeP_R_Max_70 and ThreeP_R_mean > ThreeP_R_Mean:
                return 7.5
            elif ThreeP_R_mean > ThreeP_R_Max_50 and ThreeP_R_mean > ThreeP_R_Mean:
                return 6
            elif ThreeP_R_mean > ThreeP_R_Mean and ThreeP_R_mean < ThreeP_R_Max_50:
                return 5
            elif ThreeP_R_mean < ThreeP_R_Mean and ThreeP_R_mean > ThreeP_R_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Los Angeles Clippers':
            if ThreeP_R_mean > ThreeP_R_Max_80:
                    
                return 10
            elif ThreeP_R_mean > ThreeP_R_Max_70 and ThreeP_R_mean > ThreeP_R_Mean:
                return 7.5
            elif ThreeP_R_mean > ThreeP_R_Max_50 and ThreeP_R_mean > ThreeP_R_Mean:
                return 6
            elif ThreeP_R_mean > ThreeP_R_Mean and ThreeP_R_mean < ThreeP_R_Max_50:
                return 5
            elif ThreeP_R_mean < ThreeP_R_Mean and ThreeP_R_mean > ThreeP_R_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Los Angeles Lakers':
            if ThreeP_R_mean > ThreeP_R_Max_80:
                    
                return 10
            elif ThreeP_R_mean > ThreeP_R_Max_70 and ThreeP_R_mean > ThreeP_R_Mean:
                return 7.5
            elif ThreeP_R_mean > ThreeP_R_Max_50 and ThreeP_R_mean > ThreeP_R_Mean:
                return 6
            elif ThreeP_R_mean > ThreeP_R_Mean and ThreeP_R_mean < ThreeP_R_Max_50:
                return 5
            elif ThreeP_R_mean < ThreeP_R_Mean and ThreeP_R_mean > ThreeP_R_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Memphis Grizzlies':   
            if ThreeP_R_mean > ThreeP_R_Max_80:
                    
                return 10
            elif ThreeP_R_mean > ThreeP_R_Max_70 and ThreeP_R_mean > ThreeP_R_Mean:
                return 7.5
            elif ThreeP_R_mean > ThreeP_R_Max_50 and ThreeP_R_mean > ThreeP_R_Mean:
                return 6
            elif ThreeP_R_mean > ThreeP_R_Mean and ThreeP_R_mean < ThreeP_R_Max_50:
                return 5
            elif ThreeP_R_mean < ThreeP_R_Mean and ThreeP_R_mean > ThreeP_R_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Miami Heat':
            if ThreeP_R_mean > ThreeP_R_Max_80:
                    
                return 10
            elif ThreeP_R_mean > ThreeP_R_Max_70 and ThreeP_R_mean > ThreeP_R_Mean:
                return 7.5
            elif ThreeP_R_mean > ThreeP_R_Max_50 and ThreeP_R_mean > ThreeP_R_Mean:
                return 6
            elif ThreeP_R_mean > ThreeP_R_Mean and ThreeP_R_mean < ThreeP_R_Max_50:
                return 5
            elif ThreeP_R_mean < ThreeP_R_Mean and ThreeP_R_mean > ThreeP_R_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Milwaukee Bucks':
            if ThreeP_R_mean > ThreeP_R_Max_80:
                    
                return 10
            elif ThreeP_R_mean > ThreeP_R_Max_70 and ThreeP_R_mean > ThreeP_R_Mean:
                return 7.5
            elif ThreeP_R_mean > ThreeP_R_Max_50 and ThreeP_R_mean > ThreeP_R_Mean:
                return 6
            elif ThreeP_R_mean > ThreeP_R_Mean and ThreeP_R_mean < ThreeP_R_Max_50:
                return 5
            elif ThreeP_R_mean < ThreeP_R_Mean and ThreeP_R_mean > ThreeP_R_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Minnesota Timberwolves':   
            if ThreeP_R_mean > ThreeP_R_Max_80:
                    
                return 10
            elif ThreeP_R_mean > ThreeP_R_Max_70 and ThreeP_R_mean > ThreeP_R_Mean:
                return 7.5
            elif ThreeP_R_mean > ThreeP_R_Max_50 and ThreeP_R_mean > ThreeP_R_Mean:
                return 6
            elif ThreeP_R_mean > ThreeP_R_Mean and ThreeP_R_mean < ThreeP_R_Max_50:
                return 5
            elif ThreeP_R_mean < ThreeP_R_Mean and ThreeP_R_mean > ThreeP_R_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'New Orleans Pelicans':
            if ThreeP_R_mean > ThreeP_R_Max_80:
                    
                return 10
            elif ThreeP_R_mean > ThreeP_R_Max_70 and ThreeP_R_mean > ThreeP_R_Mean:
                return 7.5
            elif ThreeP_R_mean > ThreeP_R_Max_50 and ThreeP_R_mean > ThreeP_R_Mean:
                return 6
            elif ThreeP_R_mean > ThreeP_R_Mean and ThreeP_R_mean < ThreeP_R_Max_50:
                return 5
            elif ThreeP_R_mean < ThreeP_R_Mean and ThreeP_R_mean > ThreeP_R_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'New York Knicks':
            if ThreeP_R_mean > ThreeP_R_Max_80:
                    
                return 10
            elif ThreeP_R_mean > ThreeP_R_Max_70 and ThreeP_R_mean > ThreeP_R_Mean:
                return 7.5
            elif ThreeP_R_mean > ThreeP_R_Max_50 and ThreeP_R_mean > ThreeP_R_Mean:
                return 6
            elif ThreeP_R_mean > ThreeP_R_Mean and ThreeP_R_mean < ThreeP_R_Max_50:
                return 5
            elif ThreeP_R_mean < ThreeP_R_Mean and ThreeP_R_mean > ThreeP_R_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Oklahoma City Thunder':
            if ThreeP_R_mean > ThreeP_R_Max_80:
                    
                return 10
            elif ThreeP_R_mean > ThreeP_R_Max_70 and ThreeP_R_mean > ThreeP_R_Mean:
                return 7.5
            elif ThreeP_R_mean > ThreeP_R_Max_50 and ThreeP_R_mean > ThreeP_R_Mean:
                return 6
            elif ThreeP_R_mean > ThreeP_R_Mean and ThreeP_R_mean < ThreeP_R_Max_50:
                return 5
            elif ThreeP_R_mean < ThreeP_R_Mean and ThreeP_R_mean > ThreeP_R_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Orlando Magic':
            if ThreeP_R_mean > ThreeP_R_Max_80:
                    
                return 10
            elif ThreeP_R_mean > ThreeP_R_Max_70 and ThreeP_R_mean > ThreeP_R_Mean:
                return 7.5
            elif ThreeP_R_mean > ThreeP_R_Max_50 and ThreeP_R_mean > ThreeP_R_Mean:
                return 6
            elif ThreeP_R_mean > ThreeP_R_Mean and ThreeP_R_mean < ThreeP_R_Max_50:
                return 5
            elif ThreeP_R_mean < ThreeP_R_Mean and ThreeP_R_mean > ThreeP_R_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Philadelphia 76ers':
            if ThreeP_R_mean > ThreeP_R_Max_80:
                    
                return 10
            elif ThreeP_R_mean > ThreeP_R_Max_70 and ThreeP_R_mean > ThreeP_R_Mean:
                return 7.5
            elif ThreeP_R_mean > ThreeP_R_Max_50 and ThreeP_R_mean > ThreeP_R_Mean:
                return 6
            elif ThreeP_R_mean > ThreeP_R_Mean and ThreeP_R_mean < ThreeP_R_Max_50:
                return 5
            elif ThreeP_R_mean < ThreeP_R_Mean and ThreeP_R_mean > ThreeP_R_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Phoenix Suns':
            if ThreeP_R_mean > ThreeP_R_Max_80:
                    
                return 10
            elif ThreeP_R_mean > ThreeP_R_Max_70 and ThreeP_R_mean > ThreeP_R_Mean:
                return 7.5
            elif ThreeP_R_mean > ThreeP_R_Max_50 and ThreeP_R_mean > ThreeP_R_Mean:
                return 6
            elif ThreeP_R_mean > ThreeP_R_Mean and ThreeP_R_mean < ThreeP_R_Max_50:
                return 5
            elif ThreeP_R_mean < ThreeP_R_Mean and ThreeP_R_mean > ThreeP_R_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Portland Trail Blazers':
            if ThreeP_R_mean > ThreeP_R_Max_80:
                    
                return 10
            elif ThreeP_R_mean > ThreeP_R_Max_70 and ThreeP_R_mean > ThreeP_R_Mean:
                return 7.5
            elif ThreeP_R_mean > ThreeP_R_Max_50 and ThreeP_R_mean > ThreeP_R_Mean:
                return 6
            elif ThreeP_R_mean > ThreeP_R_Mean and ThreeP_R_mean < ThreeP_R_Max_50:
                return 5
            elif ThreeP_R_mean < ThreeP_R_Mean and ThreeP_R_mean > ThreeP_R_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Sacramento Kings':
            if ThreeP_R_mean > ThreeP_R_Max_80:
                    
                return 10
            elif ThreeP_R_mean > ThreeP_R_Max_70 and ThreeP_R_mean > ThreeP_R_Mean:
                return 7.5
            elif ThreeP_R_mean > ThreeP_R_Max_50 and ThreeP_R_mean > ThreeP_R_Mean:
                return 6
            elif ThreeP_R_mean > ThreeP_R_Mean and ThreeP_R_mean < ThreeP_R_Max_50:
                return 5
            elif ThreeP_R_mean < ThreeP_R_Mean and ThreeP_R_mean > ThreeP_R_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'SAN ANTONIO':
            if ThreeP_R_mean > ThreeP_R_Max_80:
                    
                return 10
            elif ThreeP_R_mean > ThreeP_R_Max_70 and ThreeP_R_mean > ThreeP_R_Mean:
                return 7.5
            elif ThreeP_R_mean > ThreeP_R_Max_50 and ThreeP_R_mean > ThreeP_R_Mean:
                return 6
            elif ThreeP_R_mean > ThreeP_R_Mean and ThreeP_R_mean < ThreeP_R_Max_50:
                return 5
            elif ThreeP_R_mean < ThreeP_R_Mean and ThreeP_R_mean > ThreeP_R_Min:
                return 3
            else:
                return 2
            
            
            
        
        if Team == 'Toronto Raptors':
            if ThreeP_R_mean > ThreeP_R_Max_80:
                    
                return 10
            elif ThreeP_R_mean > ThreeP_R_Max_70 and ThreeP_R_mean > ThreeP_R_Mean:
                return 7.5
            elif ThreeP_R_mean > ThreeP_R_Max_50 and ThreeP_R_mean > ThreeP_R_Mean:
                return 6
            elif ThreeP_R_mean > ThreeP_R_Mean and ThreeP_R_mean < ThreeP_R_Max_50:
                return 5
            elif ThreeP_R_mean < ThreeP_R_Mean and ThreeP_R_mean > ThreeP_R_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Utah Jazz':
            if ThreeP_R_mean > ThreeP_R_Max_80:
                    
                return 10
            elif ThreeP_R_mean > ThreeP_R_Max_70 and ThreeP_R_mean > ThreeP_R_Mean:
                return 7.5
            elif ThreeP_R_mean > ThreeP_R_Max_50 and ThreeP_R_mean > ThreeP_R_Mean:
                return 6
            elif ThreeP_R_mean > ThreeP_R_Mean and ThreeP_R_mean < ThreeP_R_Max_50:
                return 5
            elif ThreeP_R_mean < ThreeP_R_Mean and ThreeP_R_mean > ThreeP_R_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Washington Wizards':
            if ThreeP_R_mean > ThreeP_R_Max_80:
                    
                return 10
            elif ThreeP_R_mean > ThreeP_R_Max_70 and ThreeP_R_mean > ThreeP_R_Mean:
                return 7.5
            elif ThreeP_R_mean > ThreeP_R_Max_50 and ThreeP_R_mean > ThreeP_R_Mean:
                return 6
            elif ThreeP_R_mean > ThreeP_R_Mean and ThreeP_R_mean < ThreeP_R_Max_50:
                return 5
            elif ThreeP_R_mean < ThreeP_R_Mean and ThreeP_R_mean > ThreeP_R_Min:
                return 3
            else:
                return 2
    
    
      
         
    else:
        return 1

# %%
merged_drop_dups['ThreeP_R_Eval'] = merged_drop_dups[['Team','ThreeP_R_mean']].apply(Compute_ThreeP_R,axis=1)
merged_drop_dups.ThreeP_R_Eval.value_counts()

# %%
# Scoring based on PTS

def Compute_PTS(data):
    Team = data[0]
    PTS = data[1]
    
    grp = merged_drop_dups.groupby('Team')
    for name,group in grp:
        PTS_Mean = group.PTS.mean()
        PTS_Max  = group.PTS.max()
        PTS_Min  = group.PTS.min()
        PTS_Max_80 = group.PTS.max()*0.80
        PTS_Max_70 = group.PTS.max()*0.70
        PTS_Max_50 = group.PTS.max()*0.50
        
    
    
        if Team == 'Atlanta Hawks':
            if PTS > PTS_Max_80:
                    
                return 10
            elif PTS > PTS_Max_70 and PTS > PTS_Mean:
                return 7.5
            elif PTS > PTS_Max_50 and PTS > PTS_Mean:
                return 6
            elif PTS > PTS_Mean and PTS < PTS_Max_50:
                return 5
            elif PTS < PTS_Mean and PTS > PTS_Min:
                return 3
            else:
                return 2
        
        
        if Team == 'Boston Celtics':
            if PTS > PTS_Max_80:
                    
                return 10
            elif PTS > PTS_Max_70 and PTS > PTS_Mean:
                return 7.5
            elif PTS > PTS_Max_50 and PTS > PTS_Mean:
                return 6
            elif PTS > PTS_Mean and PTS < PTS_Max_50:
                return 5
            elif PTS < PTS_Mean and PTS > PTS_Min:
                return 3
            else:
                return 2
            
        
        
        if Team == 'Brooklyn Nets':
            if PTS > PTS_Max_80:
                    
                return 10
            elif PTS > PTS_Max_70 and PTS > PTS_Mean:
                return 7.5
            elif PTS > PTS_Max_50 and PTS > PTS_Mean:
                return 6
            elif PTS > PTS_Mean and PTS < PTS_Max_50:
                return 5
            elif PTS < PTS_Mean and PTS > PTS_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Charlotte Hornets':        
            if PTS > PTS_Max_80:
                    
                return 10
            elif PTS > PTS_Max_70 and PTS > PTS_Mean:
                return 7.5
            elif PTS > PTS_Max_50 and PTS > PTS_Mean:
                return 6
            elif PTS > PTS_Mean and PTS < PTS_Max_50:
                return 5
            elif PTS < PTS_Mean and PTS > PTS_Min:
                return 3
            else:
                return 2
            
        
        if Team == 'Chicago Bulls':
            if PTS > PTS_Max_80:
                    
                return 10
            elif PTS > PTS_Max_70 and PTS > PTS_Mean:
                return 7.5
            elif PTS > PTS_Max_50 and PTS > PTS_Mean:
                return 6
            elif PTS > PTS_Mean and PTS < PTS_Max_50:
                return 5
            elif PTS < PTS_Mean and PTS > PTS_Min:
                return 3
            else:
                return 2
            
        
        if Team == 'Cleveland Cavaliers':
            if PTS > PTS_Max_80:
                    
                return 10
            elif PTS > PTS_Max_70 and PTS > PTS_Mean:
                return 7.5
            elif PTS > PTS_Max_50 and PTS > PTS_Mean:
                return 6
            elif PTS > PTS_Mean and PTS < PTS_Max_50:
                return 5
            elif PTS < PTS_Mean and PTS > PTS_Min:
                return 3
            else:
                return 2
            
        
        if Team == 'Dallas Mavericks':
            if PTS > PTS_Max_80:
                    
                return 10
            elif PTS > PTS_Max_70 and PTS > PTS_Mean:
                return 7.5
            elif PTS > PTS_Max_50 and PTS > PTS_Mean:
                return 6
            elif PTS > PTS_Mean and PTS < PTS_Max_50:
                return 5
            elif PTS < PTS_Mean and PTS > PTS_Min:
                return 3
            else:
                return 2
            
        
        
        if Team == 'Denver Nuggets':
            if PTS > PTS_Max_80:
                    
                return 10
            elif PTS > PTS_Max_70 and PTS > PTS_Mean:
                return 7.5
            elif PTS > PTS_Max_50 and PTS > PTS_Mean:
                return 6
            elif PTS > PTS_Mean and PTS < PTS_Max_50:
                return 5
            elif PTS < PTS_Mean and PTS > PTS_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Detroit Pistons':
            if PTS > PTS_Max_80:
                    
                return 10
            elif PTS > PTS_Max_70 and PTS > PTS_Mean:
                return 7.5
            elif PTS > PTS_Max_50 and PTS > PTS_Mean:
                return 6
            elif PTS > PTS_Mean and PTS < PTS_Max_50:
                return 5
            elif PTS < PTS_Mean and PTS > PTS_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Golden State Warrior':
            if PTS > PTS_Max_80:
                    
                return 10
            elif PTS > PTS_Max_70 and PTS > PTS_Mean:
                return 7.5
            elif PTS > PTS_Max_50 and PTS > PTS_Mean:
                return 6
            elif PTS > PTS_Mean and PTS < PTS_Max_50:
                return 5
            elif PTS < PTS_Mean and PTS > PTS_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Houston Rockets':
            if PTS > PTS_Max_80:
                    
                return 10
            elif PTS > PTS_Max_70 and PTS > PTS_Mean:
                return 7.5
            elif PTS > PTS_Max_50 and PTS > PTS_Mean:
                return 6
            elif PTS > PTS_Mean and PTS < PTS_Max_50:
                return 5
            elif PTS < PTS_Mean and PTS > PTS_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Indiana Pacers':
            if PTS > PTS_Max_80:
                    
                return 10
            elif PTS > PTS_Max_70 and PTS > PTS_Mean:
                return 7.5
            elif PTS > PTS_Max_50 and PTS > PTS_Mean:
                return 6
            elif PTS > PTS_Mean and PTS < PTS_Max_50:
                return 5
            elif PTS < PTS_Mean and PTS > PTS_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Los Angeles Clippers':
            if PTS > PTS_Max_80:
                    
                return 10
            elif PTS > PTS_Max_70 and PTS > PTS_Mean:
                return 7.5
            elif PTS > PTS_Max_50 and PTS > PTS_Mean:
                return 6
            elif PTS > PTS_Mean and PTS < PTS_Max_50:
                return 5
            elif PTS < PTS_Mean and PTS > PTS_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Los Angeles Lakers':
            if PTS > PTS_Max_80:
                    
                return 10
            elif PTS > PTS_Max_70 and PTS > PTS_Mean:
                return 7.5
            elif PTS > PTS_Max_50 and PTS > PTS_Mean:
                return 6
            elif PTS > PTS_Mean and PTS < PTS_Max_50:
                return 5
            elif PTS < PTS_Mean and PTS > PTS_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Memphis Grizzlies':   
            if PTS > PTS_Max_80:
                    
                return 10
            elif PTS > PTS_Max_70 and PTS > PTS_Mean:
                return 7.5
            elif PTS > PTS_Max_50 and PTS > PTS_Mean:
                return 6
            elif PTS > PTS_Mean and PTS < PTS_Max_50:
                return 5
            elif PTS < PTS_Mean and PTS > PTS_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Miami Heat':
            if PTS > PTS_Max_80:
                    
                return 10
            elif PTS > PTS_Max_70 and PTS > PTS_Mean:
                return 7.5
            elif PTS > PTS_Max_50 and PTS > PTS_Mean:
                return 6
            elif PTS > PTS_Mean and PTS < PTS_Max_50:
                return 5
            elif PTS < PTS_Mean and PTS > PTS_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Milwaukee Bucks':
            if PTS > PTS_Max_80:
                    
                return 10
            elif PTS > PTS_Max_70 and PTS > PTS_Mean:
                return 7.5
            elif PTS > PTS_Max_50 and PTS > PTS_Mean:
                return 6
            elif PTS > PTS_Mean and PTS < PTS_Max_50:
                return 5
            elif PTS < PTS_Mean and PTS > PTS_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Minnesota Timberwolves':   
            if PTS > PTS_Max_80:
                    
                return 10
            elif PTS > PTS_Max_70 and PTS > PTS_Mean:
                return 7.5
            elif PTS > PTS_Max_50 and PTS > PTS_Mean:
                return 6
            elif PTS > PTS_Mean and PTS < PTS_Max_50:
                return 5
            elif PTS < PTS_Mean and PTS > PTS_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'New Orleans Pelicans':
            if PTS > PTS_Max_80:
                    
                return 10
            elif PTS > PTS_Max_70 and PTS > PTS_Mean:
                return 7.5
            elif PTS > PTS_Max_50 and PTS > PTS_Mean:
                return 6
            elif PTS > PTS_Mean and PTS < PTS_Max_50:
                return 5
            elif PTS < PTS_Mean and PTS > PTS_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'New York Knicks':
            if PTS > PTS_Max_80:
                    
                return 10
            elif PTS > PTS_Max_70 and PTS > PTS_Mean:
                return 7.5
            elif PTS > PTS_Max_50 and PTS > PTS_Mean:
                return 6
            elif PTS > PTS_Mean and PTS < PTS_Max_50:
                return 5
            elif PTS < PTS_Mean and PTS > PTS_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Oklahoma City Thunder':
            if PTS > PTS_Max_80:
                    
                return 10
            elif PTS > PTS_Max_70 and PTS > PTS_Mean:
                return 7.5
            elif PTS > PTS_Max_50 and PTS > PTS_Mean:
                return 6
            elif PTS > PTS_Mean and PTS < PTS_Max_50:
                return 5
            elif PTS < PTS_Mean and PTS > PTS_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Orlando Magic':
            if PTS > PTS_Max_80:
                    
                return 10
            elif PTS > PTS_Max_70 and PTS > PTS_Mean:
                return 7.5
            elif PTS > PTS_Max_50 and PTS > PTS_Mean:
                return 6
            elif PTS > PTS_Mean and PTS < PTS_Max_50:
                return 5
            elif PTS < PTS_Mean and PTS > PTS_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Philadelphia 76ers':
            if PTS > PTS_Max_80:
                    
                return 10
            elif PTS > PTS_Max_70 and PTS > PTS_Mean:
                return 7.5
            elif PTS > PTS_Max_50 and PTS > PTS_Mean:
                return 6
            elif PTS > PTS_Mean and PTS < PTS_Max_50:
                return 5
            elif PTS < PTS_Mean and PTS > PTS_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Phoenix Suns':
            if PTS > PTS_Max_80:
                    
                return 10
            elif PTS > PTS_Max_70 and PTS > PTS_Mean:
                return 7.5
            elif PTS > PTS_Max_50 and PTS > PTS_Mean:
                return 6
            elif PTS > PTS_Mean and PTS < PTS_Max_50:
                return 5
            elif PTS < PTS_Mean and PTS > PTS_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Portland Trail Blazers':
            if PTS > PTS_Max_80:
                    
                return 10
            elif PTS > PTS_Max_70 and PTS > PTS_Mean:
                return 7.5
            elif PTS > PTS_Max_50 and PTS > PTS_Mean:
                return 6
            elif PTS > PTS_Mean and PTS < PTS_Max_50:
                return 5
            elif PTS < PTS_Mean and PTS > PTS_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Sacramento Kings':
            if PTS > PTS_Max_80:
                    
                return 10
            elif PTS > PTS_Max_70 and PTS > PTS_Mean:
                return 7.5
            elif PTS > PTS_Max_50 and PTS > PTS_Mean:
                return 6
            elif PTS > PTS_Mean and PTS < PTS_Max_50:
                return 5
            elif PTS < PTS_Mean and PTS > PTS_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'SAN ANTONIO':
            if PTS > PTS_Max_80:
                    
                return 10
            elif PTS > PTS_Max_70 and PTS > PTS_Mean:
                return 7.5
            elif PTS > PTS_Max_50 and PTS > PTS_Mean:
                return 6
            elif PTS > PTS_Mean and PTS < PTS_Max_50:
                return 5
            elif PTS < PTS_Mean and PTS > PTS_Min:
                return 3
            else:
                return 2
            
            
            
        
        if Team == 'Toronto Raptors':
            if PTS > PTS_Max_80:
                    
                return 10
            elif PTS > PTS_Max_70 and PTS > PTS_Mean:
                return 7.5
            elif PTS > PTS_Max_50 and PTS > PTS_Mean:
                return 6
            elif PTS > PTS_Mean and PTS < PTS_Max_50:
                return 5
            elif PTS < PTS_Mean and PTS > PTS_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Utah Jazz':
            if PTS > PTS_Max_80:
                    
                return 10
            elif PTS > PTS_Max_70 and PTS > PTS_Mean:
                return 7.5
            elif PTS > PTS_Max_50 and PTS > PTS_Mean:
                return 6
            elif PTS > PTS_Mean and PTS < PTS_Max_50:
                return 5
            elif PTS < PTS_Mean and PTS > PTS_Min:
                return 3
            else:
                return 2
            
            
        
        if Team == 'Washington Wizards':
            if PTS > PTS_Max_80:
                    
                return 10
            elif PTS > PTS_Max_70 and PTS > PTS_Mean:
                return 7.5
            elif PTS > PTS_Max_50 and PTS > PTS_Mean:
                return 6
            elif PTS > PTS_Mean and PTS < PTS_Max_50:
                return 5
            elif PTS < PTS_Mean and PTS > PTS_Min:
                return 3
            else:
                return 2
    
    
      
         
    else:
        return 1

# %%
merged_drop_dups['PTS_Eval'] = merged_drop_dups[['Team','PTS']].apply(Compute_PTS,axis=1)
merged_drop_dups.PTS_Eval.value_counts()

# %%
merged_drop_dups.head()

# %%
merged_drop_dups['Player_Score'] = merged_drop_dups.apply(lambda row: row.Team_Score +
                                            row.Salary_Eval+
                                            row.Exp_Eval+
                                            row.G_Eval+
                                            row.GS_Eval+
                                            row.MP_Eval+
                                            row.FGA_Eval+
                                            row.ThreeP_R_Eval+
                                            row.PTS_Eval
                                            ,axis=1)

# %%
merged_drop_dups.head(20)

# %%
class color:
    PURPLE = '\033[95m'
    CYAN = '\033[96m'
    DARKCYAN = '\033[36m'
    BLUE = '\033[94m'
    GREEN = '\033[92m'
    YELLOW = '\033[93m'
    RED = '\033[91m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'
    END = '\033[0m'

pf_merged_drop_dups = merged_drop_dups.groupby('Team')
bb = '##############################################'
x = 0
y = 0


for a,b in pf_merged_drop_dups:
    print('The name of the Team : ' +str(a))
    print('The Total Player Score is  : ' +str(b.Player_Score.sum()))
    print('The number of Players in the Team : ' +str(b.Name.count()))
    print(bb)
    if (b.Name.count()) < 12:
        x = x+1
        print('!!!!!!!!!!!!!!!!____Less_Player_Alert___!!!!!!!!!!!!!!!! :' +str(b.Name.count())+ ' Players only!!!')
        print(b.Name)
    elif(b.Name.count()) > 12:
        y =y+1  
        print('!!!!!!!!!!!!!!!!____More_Player_Alert___!!!!!!!!!!!!!!!! :' +str(b.Name.count())+ ' Players !!!')
        print(b.Name)
print(color.RED+'Total count of "Less Player" Alert is :'+color.BOLD+ str(x))
print(color.RED+'Total count of "More Player" Alert is :'+color.BOLD+ str(y))
print(color.RED+'Total count of "All" Alert is :'+color.BOLD+ str(x+y))

# %%
#to_del = df[df['Type'].isin(['UnweightedBase', 'Base'])].index.tolist()
check_df_9_player = pd.DataFrame()
delete = merged_drop_dups[merged_drop_dups['Name'].isin(['Jeremy Evans',
'Nicolas Brussino',
'John Jenkins',
'Isaiah Whitehead',
'Rondae Hollis-Jefferson',
'Joe Harris',
'Treveon Graham',
'Julyan Stone',
'David Nwaba',
'Kay Felder',
'Paul Zipser',
'Bobby Portis',
'Jerian Grant',
'Derrick Rose',
'Jeff Green',
'Dwyane Wade',
'Manny Harris',
'Salah Mejri',
'Nikola Jokic',
'Malik Beasley',
'Juan Hernangomez',
'Trey Lyles',
'Eric Moreland',
'Henry Ellenson',
'Reggie Bullock',
'Briante Weber',
'James Michael McAdoo',
'Isaiah Taylor',
'Bobby Brown',
'Montrezl Harrell',
'Joe Young',
'Glenn Robinson III',
'Damien Wilkins',
'Jordan Farmar',
'Alan Anderson',
'Anthony Brown',
'Thomas Robinson',
'Larry Nance Jr.',
'Metta World Peace',
'Toney Douglas',
'JaMychal Green',
'Jarell Martin',
'A.J. Hammons',
'Okaro White',
'Rodney McGruder',
'Jordan Mickey',
'Josh Richardson',
'Malcolm Brogdon',
'Rashad Vaughn',
'Jason Terry',
'Marcus Georges-Hunt',
'Tyus Jones',
'Shabazz Muhammad',
'Axel Toupane',
'Hollis Thompson',
'Jordan Crawford',
'Reggie Williams',
'Donatas Motiejunas',
'Terrence Jones',
'Willy Hernangomez',
'Michael Beasley',
'Jarrett Jack',
'Ramon Sessions',
'Josh Huestis',
'Jerami Grant',
'Nick Collison',
'Raymond Felton',
'Marreese Speights',
'Elfrid Payton',
'Timothe Luwawu-Cabarrot',
'Richaun Holmes',
'T.J. McConnell',
'Jarell Eddie',
'Alan Williams',
'Archie Goodwin',
'Jake Layman',
'Pat Connaughton',
'Anderson Varejao',
'Shabazz Napier',
'Ty Lawson',
'Fred VanVleet',
'Pascal Siakam',
'Norman Powell',
'K.J. McDaniels',
'Raul Neto',
'Rodney Hood',
'Ekpe Udoh',
'Carrick Felix',
'Sheldon Mac',
'Chris McCullough'])].index.tolist()

df_9_player = merged_drop_dups.drop(delete)

# %%
df_9_player.to_excel('split.xlsx')

# %%
class color:
    PURPLE = '\033[95m'
    CYAN = '\033[96m'
    DARKCYAN = '\033[36m'
    BLUE = '\033[94m'
    GREEN = '\033[92m'
    YELLOW = '\033[93m'
    RED = '\033[91m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'
    END = '\033[0m'

check_df_9_player = df_9_player.groupby('Team')
bb = '##############################################'
x = 0
y = 0


for a,b in check_df_9_player:
    
    print('The name of the Team : ' +str(a))
    print('The smallest salary is  : ' +str(b.Salary.nsmallest(6)))
    print('The Names are : ' +str(b.Name))
    print('The number of Players in the Team : ' +str(b.Name.count()))
    print(bb)
    if (b.Name.count()) < 12:
        x = x+1
        print('!!!!!!!!!!!!!!!!____Less_Player_Alert___!!!!!!!!!!!!!!!! :' +str(b.Name.count())+ ' Players only!!!')
        print(b.Name)
    elif(b.Name.count()) > 12:
        y =y+1  
        print('!!!!!!!!!!!!!!!!____More_Player_Alert___!!!!!!!!!!!!!!!! :' +str(b.Name.count())+ ' Players !!!')
        print(b.Name)
print(color.RED+'Total count of "Less Player" Alert is :'+color.BOLD+ str(x))
print(color.RED+'Total count of "More Player" Alert is :'+color.BOLD+ str(y))
print(color.RED+'Total count of "All" Alert is :'+color.BOLD+ str(x+y))

# %% [markdown]
# # SAN ANTINIO add points

# %%
df_9_player.count()

# %%
df_9_player_repl = pd.concat([df_9_player]*41, ignore_index=True)
df_9_player_repl.count()
df_9_player_repl.head(5)

# %%
df_team_score = df_9_player.groupby(['Team'], as_index=False)['Player_Score'].sum()
df_team_score.to_excel('Team_Score.xlsx')

# %%
df_team_mean = df_9_player.groupby(('Team'),as_index=False).mean()
df_team_mean.head(30)
df_team_mean.to_excel('Team_Mean.xlsx')
df_team_mean.head()

# %%
NBA_Schedule_List_1 = pd.read_excel('NBA Schedule.xlsx', sheetname='Sheet3')
NBA_Schedule_List_1.head(5)

# %%
def Compute_index_1(data):
    Read = data[0]
#    PTS = data[1]
    
    grp = NBA_Schedule_List_1['Read']
    for name in grp:
        
        
    
    
        if Read == 'Atlanta Hawks':
          
                    
                return 0
         
                    
            
        
        if Read == 'Boston Celtics':
            
                    
                return 1
            
            
        
        
        if Read == 'Brooklyn Nets':
           
                return 2
            
            
        
        if Read == 'Charlotte Hornets':        
                return 3
            
        
        if Read == 'Chicago Bulls':
           
                    
                return 4
            
            
        
        if Read == 'Cleveland Cavaliers':
            
                return 5
            
        
        if Read == 'Dallas Mavericks':
            
                return 6
            
        
        
        if Read == 'Denver Nuggets':
           
                return 7
            
            
        
        if Read == 'Detroit Pistons':
            
                return 8
            
            
        
        if Read == 'Golden State Warrior':
             
            
                return 9
            
            
        
        if Read == 'Houston Rockets':
            
                return 10
            
            
        
        if Read == 'Indiana Pacers':
            
                return 11
            
            
        
        if Read == 'Los Angeles Clippers':
            
                return 12
            
            
        
        if Read == 'Los Angeles Lakers':
                return 13
            
            
        
        if Read == 'Memphis Grizzlies':   
            
                return 14
            
            
        
        if Read == 'Miami Heat':
            
                return 15
            
            
        
        if Read == 'Milwaukee Bucks':
            
                return 16
            
            
        
        if Read == 'Minnesota Timberwolves':   
            
                return 17
            
            
        
        if Read == 'New Orleans Pelicans':
            
                return 18
            
            
        
        if Read == 'New York Knicks':
            
                return 19
            
            
        
        if Read == 'Oklahoma City Thunder':
            
                return 20
            
            
        
        if Read == 'Orlando Magic':
            
                return 21
            
            
        
        if Read == 'Philadelphia 76ers':
            
                return 22
            
            
        
        if Read == 'Phoenix Suns':
            
                return 23
            
            
        
        if Read == 'Portland Trail Blazers':
            
                return 24
            
            
        
        if Read == 'Sacramento Kings':
           
                return 25
            
            
        
        if Read == 'SAN ANTONIO':
            
                return 26
            
            
            
        
        if Read == 'Toronto Raptors':
           
                return 27
            
            
        
        if Read == 'Utah Jazz':
            
                return 28
            
            
        
        if Read == 'Washington Wizards':
            
                return 29
    
    
      
         
        else:
                return 1

# %%
NBA_Schedule_List_1['Computed_location'] = NBA_Schedule_List_1[['Read']].apply(Compute_index_1,axis=1)
 
NBA_Schedule_List_1.head(1500)
NBA_Schedule_List_1.to_excel('NBA_index_1.xlsx')

# %%
NBA_Schedule_List_2 = pd.read_excel('NBA Schedule.xlsx', sheetname='Sheet4')
NBA_Schedule_List_2.head(5)

# %%
def Compute_index_2(data):
    Read = data[0]
#    PTS = data[1]
    
    grp = NBA_Schedule_List_2['Read']
    for name in grp:
        
        
    
    
        if Read == 'Atlanta Hawks':
          
                    
                return 0
         
                    
            
        
        if Read == 'Boston Celtics':
            
                    
                return 1
            
            
        
        
        if Read == 'Brooklyn Nets':
           
                return 2
            
            
        
        if Read == 'Charlotte Hornets':        
                return 3
            
        
        if Read == 'Chicago Bulls':
           
                    
                return 4
            
            
        
        if Read == 'Cleveland Cavaliers':
            
                return 5
            
        
        if Read == 'Dallas Mavericks':
            
                return 6
            
        
        
        if Read == 'Denver Nuggets':
           
                return 7
            
            
        
        if Read == 'Detroit Pistons':
            
                return 8
            
            
        
        if Read == 'Golden State Warrior':
             
            
                return 9
            
            
        
        if Read == 'Houston Rockets':
            
                return 10
            
            
        
        if Read == 'Indiana Pacers':
            
                return 11
            
            
        
        if Read == 'Los Angeles Clippers':
            
                return 12
            
            
        
        if Read == 'Los Angeles Lakers':
                return 13
            
            
        
        if Read == 'Memphis Grizzlies':   
            
                return 14
            
            
        
        if Read == 'Miami Heat':
            
                return 15
            
            
        
        if Read == 'Milwaukee Bucks':
            
                return 16
            
            
        
        if Read == 'Minnesota Timberwolves':   
            
                return 17
            
            
        
        if Read == 'New Orleans Pelicans':
            
                return 18
            
            
        
        if Read == 'New York Knicks':
            
                return 19
            
            
        
        if Read == 'Oklahoma City Thunder':
            
                return 20
            
            
        
        if Read == 'Orlando Magic':
            
                return 21
            
            
        
        if Read == 'Philadelphia 76ers':
            
                return 22
            
            
        
        if Read == 'Phoenix Suns':
            
                return 23
            
            
        
        if Read == 'Portland Trail Blazers':
            
                return 24
            
            
        
        if Read == 'Sacramento Kings':
           
                return 25
            
            
        
        if Read == 'SAN ANTONIO':
            
                return 26
            
            
            
        
        if Read == 'Toronto Raptors':
           
                return 27
            
            
        
        if Read == 'Utah Jazz':
            
                return 28
            
            
        
        if Read == 'Washington Wizards':
            
                return 29
    
                          'ThreeP_R_Eval': 'ThreeP_R_Eval_A',
                          'PTS_Eval': 'PTS_Eval_A',
                          'Team_Score': 'Team_Score_A',
                          'Salary_Eval': 'Salary_Eval_A',
                          'Player_Score': 'Player_Score_A'}, inplace=True)

# %%
df_team_B.rename(columns={'Team': 'Team_B',
                          'Team_code': 'Team_code_B',
                          'Exp_Eval': 'Exp_Eval_B',
                          'G_Eval': 'G_Eval_B',
                          'GS_Eval': 'GS_Eval_B',
                          'MP_Eval': 'MP_Eval_B',
                          'FGA_Eval': 'FGA_Eval_B',
                          'ThreeP_R_Eval': 'ThreeP_R_Eval_B',
                          'PTS_Eval': 'PTS_Eval_B',
                          'Team_Score': 'Team_Score_B',
                          'Salary_Eval': 'Salary_Eval_B',
                          'Player_Score': 'Player_Score_B'}, inplace=True)

# %%
Final_Team_list = pd.concat([df_team_A,df_team_B],axis=1)
Final_Team_list.head()

# %%
def que(Final_Team_list):
    if Final_Team_list['Player_Score_A'] > Final_Team_list['Player_Score_B']:
        return 1
    else:
        return 0
Final_Team_list['Label'] = Final_Team_list.apply(que, axis=1)

# %%
#def que(Final_Team_list):
#    if Final_Team_list['Player_Score_A'] > Final_Team_list['Player_Score_B']:
#       return 1
#    else:
#        return 0
#Final_Team_list['Label'] = Final_Team_list.apply(que, axis=1)

# %%
Final_Team_list.head(10)

# %%
Final_Team_list.columns

# %%
 

drop_cols = Final_Team_list[['Shoots_mean','Exp_mean','Age_mean',
                        'G_mean','GS_mean','MP_mean',
                        'FG_mean','FGA_mean','FG_R_mean',
                        'ThreeP_R_mean','ThreePA_R_mean','ThreePPct_R',
                        'TwoP_R','TwoPA_R','TwoPPct_R',
                        'eFG_R','FT','FTA',
                        'FTPct_R','ORB','DRB',
                        'TRB','AST','STL',
                        'BLK','TOV','PF',
                        'PTS','Team_A','Team_B','Salary',
                        'Team_Label','Label']]



X = Final_Team_list.drop(drop_cols, axis=1)
X.to_csv('Data_to_Predict1', index=False)
 
y = Final_Team_list['Label']

# %%
X.head()

# %%
y.head()

# %%
# prepare configuration for cross validation test harness
seed = 7
# prepare models
models = []
models.append(('LR', LogisticRegression()))
models.append(('LDA', LinearDiscriminantAnalysis()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier()))
models.append(('NB', GaussianNB()))
models.append(('SVM', SVC()))
# evaluate each model in turn
results = []
names = []
scoring = 'accuracy'
for name, model in models:
    kfold = model_selection.KFold(n_splits=10, random_state=seed)
    cv_results = model_selection.cross_val_score(model, X, y, cv=kfold, scoring=scoring)
    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# boxplot algorithm comparison
fig = plt.figure()
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()

# %%
from sklearn.cross_validation import train_test_split

# %%
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=100)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=1)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel = LogisticRegression()

# %%
logmodel.fit(X_train,y_train)

# %%
predictions = logmodel.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,predictions))

# %%
from sklearn.metrics import confusion_matrix

# %%
print(confusion_matrix(y_test,predictions))

# %%
#last_df = final_df.merge(predicted_value, how='left')
#last_df
#same players in different teams is creating a duplicate row

# %%
dodo = pd.read_csv('Data_to_Predict1')
dodo.head()

# %%
predictions_final = logmodel.predict(dodo)

# %%
save = pd.DataFrame({
        
        "Prediction": predictions_final
    })
save.to_csv('Final_Prediction_outcome1.csv', index=False)
save.head()

# %%
final = pd.concat([Final_Team_list,save], axis=1)
final.to_excel('NBA_Prediction_Result.xlsx')

# %%
final

# %%
for index, row in final.iterrows():
    #print(row)
    if row.Prediction == 0:
        print('In the Match between  '+row.Team_A+'  and   '+ row.Team_B+ '  :>>  '+row.Team_A+' will loose !')
    if row.Prediction == 1:
        print('In the Match between  '+row.Team_A+'  and  '+ row.Team_B+ '  :>>  '+row.Team_A+' will win !')
        
# Threat vulnerability impact/consequences probability action

# %%
for i, j in final.groupby('Team_A'):
    count = j.Label.sum()
    print('Team name is ' +str(i)+' and win count is : ' +str(count))
    print()
